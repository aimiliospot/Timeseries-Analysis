# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
# Out:
# 2024-05-01 11:18:49.352125: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-05-01 11:18:49.357723: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-05-01 11:18:49.427238: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-01 11:18:51.941742: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
def plot_series(time, series, format="-", start=0, end=None):
    """
    Visualizes time series data

    Args:
      time (array of int) - contains the time steps
      series (array of int) - contains the measurements for each time step
      format - line style when plotting the graph
      label - tag for the line
      start - first time step to plot
      end - last time step to plot
    """

    # Setup dimensions of the graph figure
    plt.figure(figsize=(10, 6))

    if type(series) is tuple:

      for series_num in series:
        # Plot the time series data
        plt.plot(time[start:end], series_num[start:end], format)

    else:
      # Plot the time series data
      plt.plot(time[start:end], series[start:end], format)

    # Label the x-axis
    plt.xlabel("Time")

    # Label the y-axis
    plt.ylabel("Value")

    # Overlay a grid on the graph
    plt.grid(True)

    # Draw the graph on screen
    plt.show()

def trend(time, slope=0):
    """
    Generates synthetic data that follows a straight line given a slope value.

    Args:
      time (array of int) - contains the time steps
      slope (float) - determines the direction and steepness of the line

    Returns:
      series (array of float) - measurements that follow a straight line
    """

    # Compute the linear series given the slope
    series = slope * time

    return series

def seasonal_pattern(season_time):
    """
    Just an arbitrary pattern, you can change it if you wish

    Args:
      season_time (array of float) - contains the measurements per time step

    Returns:
      data_pattern (array of float) -  contains revised measurement values according
                                  to the defined pattern
    """

    # Generate the values using an arbitrary pattern
    data_pattern = np.where(season_time < 0.4,
                    np.cos(season_time * 2 * np.pi),
                    1 / np.exp(3 * season_time))

    return data_pattern

def seasonality(time, period, amplitude=1, phase=0):
    """
    Repeats the same pattern at each period

    Args:
      time (array of int) - contains the time steps
      period (int) - number of time steps before the pattern repeats
      amplitude (int) - peak measured value in a period
      phase (int) - number of time steps to shift the measured values

    Returns:
      data_pattern (array of float) - seasonal data scaled by the defined amplitude
    """

    # Define the measured values per period
    season_time = ((time + phase) % period) / period

    # Generates the seasonal data scaled by the defined amplitude
    data_pattern = amplitude * seasonal_pattern(season_time)

    return data_pattern

def noise(time, noise_level=1, seed=None):
    """Generates a normally distributed noisy signal

    Args:
      time (array of int) - contains the time steps
      noise_level (float) - scaling factor for the generated signal
      seed (int) - number generator seed for repeatability

    Returns:
      noise (array of float) - the noisy signal
    """

    # Initialize the random number generator
    rnd = np.random.RandomState(seed)

    # Generate a random number for each time step and scale by the noise level
    noise = rnd.randn(len(time)) * noise_level

    return noise


time = np.arange(7 * 365 + 1, dtype="float32")
baseline = 10
amplitude = 50
slope = 0.1
noise_level = 5

# Create the series
series = baseline + trend(time, slope) + seasonality(time, period=365, amplitude=amplitude)

# Update with noise
series += noise(time, noise_level, seed=42)

# Plot the results
plot_series(time, series)

# %%
split_time = 365*6-100

# Get the train set
time_train = time[:split_time]
x_train = series[:split_time]

# Get the validation set
time_valid = time[split_time:]
x_valid = series[split_time:]

plot_series(time_train, x_train)
plot_series(time_valid, x_valid)

# %%
x_train_reshaped = x_train.reshape(-1, 1)
x_valid_reshaped = x_valid.reshape(-1, 1)
plot_series(time_train, x_train_reshaped)
plot_series(time_valid, x_valid_reshaped)

# %%
window_size = 30

x_train_window =[]
y_train_window =[]
x_valid_window =[]
y_valid_window =[]

for i in range (window_size, split_time):
    x_train_window.append(x_train_reshaped[i-window_size:i, 0])
    y_train_window.append(x_train_reshaped[i, 0])



for i in range (window_size,time_valid.shape[0] ):
  x_valid_window.append(x_valid_reshaped[i-window_size:i,0])
  y_valid_window.append(x_valid_reshaped[i,0])

X_train, y_train, X_valid, y_valid = np.array(x_train_window), np.array(y_train_window), np.array(x_valid_window), np.array(y_valid_window)

# %%
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, Dropout
from keras.optimizers import Adam
import matplotlib.pyplot as plt
from keras.metrics import MeanAbsoluteError
from keras.callbacks import ModelCheckpoint

# Initialising the RNN
regressor = Sequential()

# Adding the first SimpleRNN layer and some Dropout regularisation
regressor.add(SimpleRNN(units=50, input_shape=(X_train.shape[1], 1), activation='relu', return_sequences=True))
regressor.add(Dropout(0.2))


regressor.add(SimpleRNN(units=50, input_shape=(X_train.shape[1], 1), activation='relu', return_sequences=True))
regressor.add(Dropout(0.2))

regressor.add(SimpleRNN(units=50, input_shape=(X_train.shape[1], 1), activation='relu', return_sequences=True))
regressor.add(Dropout(0.2))

regressor.add(SimpleRNN(units=50, activation='relu'))
regressor.add(Dropout(0.2))
# Adding the output layer
regressor.add(Dense(units=1))



# Compile the model with Adam optimizer and specific learning rate
optimizer = Adam()
regressor.compile(optimizer=optimizer, loss='mean_squared_error', metrics=[MeanAbsoluteError()])

# Define a ModelCheckpoint callback to save the best model
checkpoint = ModelCheckpoint('best_model_SimpleRNN_3_50.keras', monitor='val_mean_absolute_error', mode='min', save_best_only=True)

# Fitting the RNN to the Training set with the ModelCheckpoint callback
history = regressor.fit(X_train, y_train, epochs=1000, batch_size=64, validation_data=(X_valid, y_valid), verbose=1, callbacks=[checkpoint])

# Plotting the training and validation loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

plt.plot(history.history['mean_absolute_error'], label='Training MAE')
plt.plot(history.history['val_mean_absolute_error'], label='Validation MAE')
plt.xlabel('Epoch')
plt.ylabel('MAE')
plt.title('Training and Validation MAE')
plt.legend()
plt.show()
# Out:
# Epoch 1/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - loss: 3321.9290 - mean_absolute_error: 41.9040 - val_loss: 1991.2273 - val_mean_absolute_error: 43.8262
# Epoch 2/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1111.0800 - mean_absolute_error: 24.2612 - val_loss: 2575.1169 - val_mean_absolute_error: 50.0459
# Epoch 3/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 873.3204 - mean_absolute_error: 21.3302 - val_loss: 3326.0623 - val_mean_absolute_error: 57.0723
# Epoch 4/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 618.7731 - mean_absolute_error: 18.3273 - val_loss: 1658.3728 - val_mean_absolute_error: 39.9046
# Epoch 5/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 625.6832 - mean_absolute_error: 18.4143 - val_loss: 2834.8452 - val_mean_absolute_error: 52.5787
# Epoch 6/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 508.1604 - mean_absolute_error: 16.9330 - val_loss: 1997.9778 - val_mean_absolute_error: 43.9592
# Epoch 7/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 521.4797 - mean_absolute_error: 16.8224 - val_loss: 3164.4744 - val_mean_absolute_error: 55.6412
# Epoch 8/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 555.3600 - mean_absolute_error: 17.5218 - val_loss: 2986.8384 - val_mean_absolute_error: 54.0136
# Epoch 9/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 474.7826 - mean_absolute_error: 16.1157 - val_loss: 2916.8362 - val_mean_absolute_error: 53.3512
# Epoch 10/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 466.9562 - mean_absolute_error: 15.7770 - val_loss: 3825.4565 - val_mean_absolute_error: 61.2579
# Epoch 11/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 413.8391 - mean_absolute_error: 15.0241 - val_loss: 2047.9524 - val_mean_absolute_error: 44.5034
# Epoch 12/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 417.8443 - mean_absolute_error: 15.0504 - val_loss: 3741.0120 - val_mean_absolute_error: 60.5625
# Epoch 13/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 459.1462 - mean_absolute_error: 15.3568 - val_loss: 2095.5520 - val_mean_absolute_error: 45.0467
# Epoch 14/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 382.5828 - mean_absolute_error: 14.5615 - val_loss: 4265.5220 - val_mean_absolute_error: 64.7328
# Epoch 15/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 408.8223 - mean_absolute_error: 14.9780 - val_loss: 2946.3289 - val_mean_absolute_error: 53.6189
# Epoch 16/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 362.0283 - mean_absolute_error: 14.2234 - val_loss: 3304.1792 - val_mean_absolute_error: 56.8340
# Epoch 17/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 360.1527 - mean_absolute_error: 13.8719 - val_loss: 3518.4363 - val_mean_absolute_error: 58.6961
# Epoch 18/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 384.2370 - mean_absolute_error: 14.4537 - val_loss: 2822.0730 - val_mean_absolute_error: 52.4524
# Epoch 19/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 434.4449 - mean_absolute_error: 15.4275 - val_loss: 4398.8906 - val_mean_absolute_error: 65.7239
# Epoch 20/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 349.1554 - mean_absolute_error: 14.0926 - val_loss: 3742.7993 - val_mean_absolute_error: 60.5396
# Epoch 21/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 377.4745 - mean_absolute_error: 14.0547 - val_loss: 3629.5388 - val_mean_absolute_error: 59.6390
# Epoch 22/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 370.8030 - mean_absolute_error: 14.2706 - val_loss: 4311.4756 - val_mean_absolute_error: 65.0615
# Epoch 23/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 360.3243 - mean_absolute_error: 14.0466 - val_loss: 2508.1414 - val_mean_absolute_error: 49.4036
# Epoch 24/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 355.7807 - mean_absolute_error: 14.0417 - val_loss: 2957.6606 - val_mean_absolute_error: 53.7068
# Epoch 25/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 366.1967 - mean_absolute_error: 14.0266 - val_loss: 3139.2456 - val_mean_absolute_error: 55.3779
# Epoch 26/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 335.1987 - mean_absolute_error: 13.4087 - val_loss: 3224.2402 - val_mean_absolute_error: 56.1520
# Epoch 27/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 362.4432 - mean_absolute_error: 14.0239 - val_loss: 3569.1118 - val_mean_absolute_error: 59.1127
# Epoch 28/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 344.0143 - mean_absolute_error: 13.8145 - val_loss: 3546.9177 - val_mean_absolute_error: 58.9499
# Epoch 29/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 380.7047 - mean_absolute_error: 14.2903 - val_loss: 3891.8472 - val_mean_absolute_error: 61.8077
# Epoch 30/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 341.1207 - mean_absolute_error: 13.6523 - val_loss: 3816.9641 - val_mean_absolute_error: 61.2017
# Epoch 31/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 323.0800 - mean_absolute_error: 13.3961 - val_loss: 3080.7190 - val_mean_absolute_error: 54.8808
# Epoch 32/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 386.0616 - mean_absolute_error: 14.5790 - val_loss: 3236.9172 - val_mean_absolute_error: 56.2884
# Epoch 33/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 361.1855 - mean_absolute_error: 14.1955 - val_loss: 2345.4807 - val_mean_absolute_error: 47.7167
# Epoch 34/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 295.7575 - mean_absolute_error: 12.7435 - val_loss: 5172.5830 - val_mean_absolute_error: 71.3756
# Epoch 35/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 424.7672 - mean_absolute_error: 14.9424 - val_loss: 3255.0708 - val_mean_absolute_error: 56.4624
# Epoch 36/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 332.6334 - mean_absolute_error: 13.3927 - val_loss: 3159.5195 - val_mean_absolute_error: 55.5828
# Epoch 37/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 318.2771 - mean_absolute_error: 13.0947 - val_loss: 2887.2825 - val_mean_absolute_error: 53.0996
# Epoch 38/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 351.6516 - mean_absolute_error: 13.8372 - val_loss: 3182.6042 - val_mean_absolute_error: 55.8111
# Epoch 39/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 331.2157 - mean_absolute_error: 13.4598 - val_loss: 2378.8096 - val_mean_absolute_error: 48.1036
# Epoch 40/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 302.4904 - mean_absolute_error: 12.6562 - val_loss: 3217.2632 - val_mean_absolute_error: 56.1276
# Epoch 41/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 343.3035 - mean_absolute_error: 13.3245 - val_loss: 3299.9092 - val_mean_absolute_error: 56.8445
# Epoch 42/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 308.2268 - mean_absolute_error: 12.9131 - val_loss: 2775.8877 - val_mean_absolute_error: 52.0466
# Epoch 43/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 289.6442 - mean_absolute_error: 12.5932 - val_loss: 2196.2932 - val_mean_absolute_error: 46.1448
# Epoch 44/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 309.9233 - mean_absolute_error: 12.8640 - val_loss: 2264.7031 - val_mean_absolute_error: 46.8973
# Epoch 45/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 300.7338 - mean_absolute_error: 12.7826 - val_loss: 2065.0208 - val_mean_absolute_error: 44.7050
# Epoch 46/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 300.2714 - mean_absolute_error: 12.9907 - val_loss: 1108.2673 - val_mean_absolute_error: 32.3366
# Epoch 47/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 389.8312 - mean_absolute_error: 14.7597 - val_loss: 3086.7366 - val_mean_absolute_error: 54.9664
# Epoch 48/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 316.3413 - mean_absolute_error: 13.0940 - val_loss: 4626.3364 - val_mean_absolute_error: 67.4653
# Epoch 49/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 377.2468 - mean_absolute_error: 14.1518 - val_loss: 2297.0645 - val_mean_absolute_error: 47.2543
# Epoch 50/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 285.9596 - mean_absolute_error: 12.5121 - val_loss: 1939.0959 - val_mean_absolute_error: 43.2974
# Epoch 51/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 311.6412 - mean_absolute_error: 13.1417 - val_loss: 1509.9678 - val_mean_absolute_error: 38.0160
# Epoch 52/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 314.6586 - mean_absolute_error: 13.0255 - val_loss: 3555.2085 - val_mean_absolute_error: 59.0173
# Epoch 53/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 297.2721 - mean_absolute_error: 12.5693 - val_loss: 3233.6118 - val_mean_absolute_error: 56.2461
# Epoch 54/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 302.1437 - mean_absolute_error: 12.9135 - val_loss: 2289.4402 - val_mean_absolute_error: 47.1544
# Epoch 55/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 287.7469 - mean_absolute_error: 12.5173 - val_loss: 2350.9800 - val_mean_absolute_error: 47.7952
# Epoch 56/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 313.8778 - mean_absolute_error: 12.9877 - val_loss: 2422.0110 - val_mean_absolute_error: 48.4907
# Epoch 57/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 306.1943 - mean_absolute_error: 13.0114 - val_loss: 2773.6416 - val_mean_absolute_error: 51.9881
# Epoch 58/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 290.9915 - mean_absolute_error: 12.6654 - val_loss: 4366.8579 - val_mean_absolute_error: 65.5072
# Epoch 59/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 277.3911 - mean_absolute_error: 12.3942 - val_loss: 3216.6099 - val_mean_absolute_error: 56.0983
# Epoch 60/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 279.3675 - mean_absolute_error: 12.3954 - val_loss: 2271.6213 - val_mean_absolute_error: 46.9926
# Epoch 61/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 317.5345 - mean_absolute_error: 13.0045 - val_loss: 2788.1255 - val_mean_absolute_error: 52.1874
# Epoch 62/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 291.2390 - mean_absolute_error: 12.8151 - val_loss: 4105.1426 - val_mean_absolute_error: 63.5036
# Epoch 63/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 287.1507 - mean_absolute_error: 12.6282 - val_loss: 2596.7610 - val_mean_absolute_error: 50.3198
# Epoch 64/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 289.7569 - mean_absolute_error: 12.3345 - val_loss: 3323.7874 - val_mean_absolute_error: 57.0281
# Epoch 65/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 265.0472 - mean_absolute_error: 12.0208 - val_loss: 2448.1018 - val_mean_absolute_error: 48.8140
# Epoch 66/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 280.3012 - mean_absolute_error: 12.4230 - val_loss: 2672.0688 - val_mean_absolute_error: 51.0260
# Epoch 67/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 263.9652 - mean_absolute_error: 12.0736 - val_loss: 2858.7444 - val_mean_absolute_error: 52.8087
# Epoch 68/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 268.1484 - mean_absolute_error: 12.2696 - val_loss: 2332.4390 - val_mean_absolute_error: 47.5932
# Epoch 69/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 325.7456 - mean_absolute_error: 13.3367 - val_loss: 1563.5511 - val_mean_absolute_error: 38.7735
# Epoch 70/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 329.2429 - mean_absolute_error: 13.2225 - val_loss: 3095.0791 - val_mean_absolute_error: 55.0361
# Epoch 71/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 310.5009 - mean_absolute_error: 12.9303 - val_loss: 3516.7668 - val_mean_absolute_error: 58.7097
# Epoch 72/1000
# 15/33 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 285.9880 - mean_absolute_error: 12.2421

# %%
# Find the epoch for the lowest MAE for training and validation
min_train_mae = min(history.history['mean_absolute_error'])
min_val_mae = min(history.history['val_mean_absolute_error'])

min_train_loss = min(history.history['loss'])
min_val_loss = min(history.history['val_loss'])

min_train_mae_epoch = history.history['mean_absolute_error'].index(min_train_mae) + 1
min_val_mae_epoch = history.history['val_mean_absolute_error'].index(min_val_mae) + 1

# Find the epoch for the lowest loss for training and validation
min_train_loss_epoch = history.history['loss'].index(min_train_loss) + 1
min_val_loss_epoch = history.history['val_loss'].index(min_val_loss) + 1

print("Lowest MAE for training: {:.4f} at epoch {}".format(min_train_mae, min_train_mae_epoch))
print("Lowest MAE for validation: {:.4f} at epoch {}".format(min_val_mae, min_val_mae_epoch))

print("Lowest loss for training: {:.4f} at epoch {}".format(min_train_loss, min_train_loss_epoch))
print("Lowest loss for validation: {:.4f} at epoch {}".format(min_val_loss, min_val_loss_epoch))

# %%
from keras.models import load_model
loaded_model = load_model ('best_model_SimpleRNN_3_50.keras')

loss, mae = loaded_model.evaluate(X_valid, y_valid)

print("Validation Loss:", loss)
print("Validation Mean Absolute Error:", mae)

# %%
y_pred = loaded_model.predict(X_valid)

# %%
import matplotlib.pyplot as plt

# Assuming timestamps are available for both y_pred and y_valid
timestamps = range(len(y_valid))

# Plot y_pred vs y_valid
plt.figure(figsize=(10, 6))
plt.plot(timestamps, y_valid, label='Actual', color='blue')
plt.plot(timestamps, y_pred, label='Predicted', color='red')
plt.title('Actual vs Predicted Time Series')
plt.xlabel('Time')
plt.ylabel('Value')
plt.legend()
plt.show()

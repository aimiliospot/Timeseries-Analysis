# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# Out:
# 2024-05-01 15:32:11.588143: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-05-01 15:32:11.594296: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-05-01 15:32:11.664084: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-01 15:32:13.323630: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
def plot_series(time, series, format="-", start=0, end=None):
    """
    Visualizes time series data

    Args:
      time (array of int) - contains the time steps
      series (array of int) - contains the measurements for each time step
      format - line style when plotting the graph
      label - tag for the line
      start - first time step to plot
      end - last time step to plot
    """

    # Setup dimensions of the graph figure
    plt.figure(figsize=(10, 6))

    if type(series) is tuple:

      for series_num in series:
        # Plot the time series data
        plt.plot(time[start:end], series_num[start:end], format)

    else:
      # Plot the time series data
      plt.plot(time[start:end], series[start:end], format)

    # Label the x-axis
    plt.xlabel("Time")

    # Label the y-axis
    plt.ylabel("Value")

    # Overlay a grid on the graph
    plt.grid(True)

    # Draw the graph on screen
    plt.show()

def trend(time, slope=0):
    """
    Generates synthetic data that follows a straight line given a slope value.

    Args:
      time (array of int) - contains the time steps
      slope (float) - determines the direction and steepness of the line

    Returns:
      series (array of float) - measurements that follow a straight line
    """

    # Compute the linear series given the slope
    series = slope * time

    return series

def seasonal_pattern(season_time):
    """
    Just an arbitrary pattern, you can change it if you wish

    Args:
      season_time (array of float) - contains the measurements per time step

    Returns:
      data_pattern (array of float) -  contains revised measurement values according
                                  to the defined pattern
    """

    # Generate the values using an arbitrary pattern
    data_pattern = np.where(season_time < 0.4,
                    np.cos(season_time * 2 * np.pi),
                    1 / np.exp(3 * season_time))

    return data_pattern

def seasonality(time, period, amplitude=1, phase=0):
    """
    Repeats the same pattern at each period

    Args:
      time (array of int) - contains the time steps
      period (int) - number of time steps before the pattern repeats
      amplitude (int) - peak measured value in a period
      phase (int) - number of time steps to shift the measured values

    Returns:
      data_pattern (array of float) - seasonal data scaled by the defined amplitude
    """

    # Define the measured values per period
    season_time = ((time + phase) % period) / period

    # Generates the seasonal data scaled by the defined amplitude
    data_pattern = amplitude * seasonal_pattern(season_time)

    return data_pattern

def noise(time, noise_level=1, seed=None):
    """Generates a normally distributed noisy signal

    Args:
      time (array of int) - contains the time steps
      noise_level (float) - scaling factor for the generated signal
      seed (int) - number generator seed for repeatability

    Returns:
      noise (array of float) - the noisy signal
    """

    # Initialize the random number generator
    rnd = np.random.RandomState(seed)

    # Generate a random number for each time step and scale by the noise level
    noise = rnd.randn(len(time)) * noise_level

    return noise

def normalize_data(train_data, valid_data):
    """
    Normalize training and validation data to the range [0, 1] based on the combined minimum and maximum values.
    
    Parameters:
    train_data (array-like): The training data to be normalized.
    valid_data (array-like): The validation data to be normalized.
    
    Returns:
    tuple: A tuple containing the normalized training and validation data.
    """
    combined_data = train_data + valid_data
    min_val = min(combined_data)
    max_val = max(combined_data)
    normalized_train_data = [(x - min_val) / (max_val - min_val) for x in train_data]
    normalized_valid_data = [(x - min_val) / (max_val - min_val) for x in valid_data]
    return normalized_train_data, normalized_valid_data


time = np.arange(7 * 365 + 1, dtype="float32")
baseline = 10
amplitude = 50
slope = 0.1
noise_level = 5

# Create the series
series = baseline + trend(time, slope) + seasonality(time, period=365, amplitude=amplitude)

# Update with noise
series += noise(time, noise_level, seed=42)

# Plot the results
plot_series(time, series)

# %%
split_time = 365*6-100

# Get the train set
time_train = time[:split_time]
x_train = series[:split_time]

# Get the validation set
time_valid = time[split_time:]
x_valid = series[split_time:]

plot_series(time_train, x_train)
plot_series(time_valid, x_valid)

# %%
x_train_reshaped = x_train.reshape(-1, 1)
x_valid_reshaped = x_valid.reshape(-1, 1)

plot_series(time_train, x_train_reshaped)
plot_series(time_valid, x_valid_reshaped)

# %%
window_size = 30

x_train_window =[]
y_train_window =[]
x_valid_window =[]
y_valid_window =[]

for i in range (window_size, split_time):
    x_train_window.append(x_train_reshaped[i-window_size:i, 0])
    y_train_window.append(x_train_reshaped[i, 0])



for i in range (window_size,time_valid.shape[0] ):
  x_valid_window.append(x_valid_reshaped[i-window_size:i,0])
  y_valid_window.append(x_valid_reshaped[i,0])

X_train, y_train, X_valid, y_valid = np.array(x_train_window), np.array(y_train_window), np.array(x_valid_window), np.array(y_valid_window)

# %%
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, Dropout
from keras.optimizers import Adam
import matplotlib.pyplot as plt
from keras.metrics import MeanAbsoluteError
from keras.callbacks import ModelCheckpoint
import itertools

# Define the hyperparameters you want to iterate over
activations = ['relu', 'tanh']
num_of_layers = [1, 2, 3]
units = 50
dropout_rate = 0.2

# Loop over the combinations
for activation, num_layers in itertools.product(activations, num_of_layers):
    print(f"Training Neural Network: Activation={activation}, Num Layers={num_layers}")
    # Initialising the RNN
    regressor = Sequential()

    # Adding the first SimpleRNN layer and some Dropout regularisation
    regressor.add(SimpleRNN(units=units, input_shape=(X_train.shape[1], 1), activation=activation, return_sequences=True))
    regressor.add(Dropout(dropout_rate))

    # Adding more SimpleRNN layers
    for _ in range(num_layers - 1):
        regressor.add(SimpleRNN(units=units, activation=activation, return_sequences=True))
        regressor.add(Dropout(dropout_rate))

    # Adding the output layer
    regressor.add(Dense(units=1))

    # Compile the model with Adam optimizer and specific learning rate
    optimizer = Adam()
    regressor.compile(optimizer=optimizer, loss='mean_squared_error', metrics=[MeanAbsoluteError()])

    # Define a ModelCheckpoint callback to save the best model
    checkpoint = ModelCheckpoint(f'best_model_SimpleRNN_{num_layers}_{units}_{activation}.keras', monitor='val_mean_absolute_error', mode='min', save_best_only=True)

    # Fitting the RNN to the Training set with the ModelCheckpoint callback
    history = regressor.fit(X_train, y_train, epochs=1000, batch_size=64, validation_data=(X_valid, y_valid), verbose=1, callbacks=[checkpoint])

    history_df = pd.DataFrame({
        'epoch': range(1, len(history.history['loss']) + 1),
        'loss': history.history['loss'],
        'val_loss': history.history['val_loss'],
        'mean_absolute_error': history.history['mean_absolute_error'],
        'val_mean_absolute_error': history.history['val_mean_absolute_error']
    })
    history_df.to_csv(f'training_history_{num_layers}_{units}_{activation}.csv', index=False)
# Out:
# Training Neural Network: Activation=relu, Num Layers=1
# Epoch 1/1000
# 2024-05-01 15:30:01.919799: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-01 15:30:01.920978: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# /home/p/pakrit/pytorchRL/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 14518.7568 - mean_absolute_error: 101.8315 - val_loss: 4280.5767 - val_mean_absolute_error: 58.0480
# Epoch 2/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7285.0518 - mean_absolute_error: 69.4790 - val_loss: 3315.2151 - val_mean_absolute_error: 50.4261
# Epoch 3/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7154.6777 - mean_absolute_error: 68.7777 - val_loss: 2637.8047 - val_mean_absolute_error: 44.0041
# Epoch 4/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6991.9834 - mean_absolute_error: 67.9289 - val_loss: 3226.5532 - val_mean_absolute_error: 49.9647
# Epoch 5/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6355.2856 - mean_absolute_error: 65.1841 - val_loss: 4003.9932 - val_mean_absolute_error: 58.5185
# Epoch 6/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5947.0347 - mean_absolute_error: 63.0541 - val_loss: 7408.2563 - val_mean_absolute_error: 82.8313
# Epoch 7/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5750.1763 - mean_absolute_error: 62.2532 - val_loss: 8410.6660 - val_mean_absolute_error: 89.0474
# Epoch 8/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5967.8496 - mean_absolute_error: 63.2041 - val_loss: 7704.5264 - val_mean_absolute_error: 84.7030
# Epoch 9/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5353.8687 - mean_absolute_error: 60.1617 - val_loss: 7278.4497 - val_mean_absolute_error: 81.8695
# Epoch 10/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5271.6509 - mean_absolute_error: 60.0262 - val_loss: 7296.9434 - val_mean_absolute_error: 81.6165
# Epoch 11/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5450.2744 - mean_absolute_error: 61.1825 - val_loss: 6995.9609 - val_mean_absolute_error: 80.1839
# Epoch 12/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5167.7974 - mean_absolute_error: 59.5627 - val_loss: 9163.1748 - val_mean_absolute_error: 93.0299
# Epoch 13/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5328.8965 - mean_absolute_error: 60.3529 - val_loss: 8497.7676 - val_mean_absolute_error: 89.5189
# Epoch 14/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5235.1050 - mean_absolute_error: 59.9027 - val_loss: 7750.8945 - val_mean_absolute_error: 84.7714
# Epoch 15/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4984.9648 - mean_absolute_error: 58.6475 - val_loss: 9520.2061 - val_mean_absolute_error: 94.8390
# Epoch 16/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4948.2559 - mean_absolute_error: 58.1412 - val_loss: 8961.4062 - val_mean_absolute_error: 91.8769
# Epoch 17/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5049.6860 - mean_absolute_error: 58.9395 - val_loss: 8794.5674 - val_mean_absolute_error: 91.0616
# Epoch 18/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4883.6748 - mean_absolute_error: 58.1820 - val_loss: 8968.1875 - val_mean_absolute_error: 92.0463
# Epoch 19/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4882.3096 - mean_absolute_error: 57.7893 - val_loss: 10609.4990 - val_mean_absolute_error: 100.6004
# Epoch 20/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5038.7822 - mean_absolute_error: 58.8290 - val_loss: 9751.9609 - val_mean_absolute_error: 96.2327
# Epoch 21/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5222.6279 - mean_absolute_error: 59.3707 - val_loss: 7802.1997 - val_mean_absolute_error: 85.3964
# Epoch 22/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4957.3022 - mean_absolute_error: 58.3764 - val_loss: 6375.1943 - val_mean_absolute_error: 76.9786
# Epoch 23/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4890.1816 - mean_absolute_error: 57.9303 - val_loss: 8704.0742 - val_mean_absolute_error: 90.6581
# Epoch 24/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4895.6699 - mean_absolute_error: 58.4694 - val_loss: 8103.0688 - val_mean_absolute_error: 87.2838
# Epoch 25/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4774.8135 - mean_absolute_error: 57.5057 - val_loss: 9147.5811 - val_mean_absolute_error: 92.8389
# Epoch 26/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4799.2524 - mean_absolute_error: 57.5329 - val_loss: 5823.8281 - val_mean_absolute_error: 73.1545
# Epoch 27/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5091.3994 - mean_absolute_error: 59.2573 - val_loss: 7326.7524 - val_mean_absolute_error: 83.0656
# Epoch 28/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4993.1211 - mean_absolute_error: 58.5055 - val_loss: 8528.6367 - val_mean_absolute_error: 89.9456
# Epoch 29/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4868.4175 - mean_absolute_error: 57.9695 - val_loss: 6885.0884 - val_mean_absolute_error: 80.2517
# Epoch 30/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4898.0259 - mean_absolute_error: 58.4275 - val_loss: 8966.2148 - val_mean_absolute_error: 92.2318
# Epoch 31/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4721.2104 - mean_absolute_error: 57.1885 - val_loss: 10234.6328 - val_mean_absolute_error: 98.6970
# Epoch 32/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4763.0723 - mean_absolute_error: 57.7425 - val_loss: 9532.3994 - val_mean_absolute_error: 95.2546
# Epoch 33/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4791.1558 - mean_absolute_error: 57.8051 - val_loss: 7893.0547 - val_mean_absolute_error: 86.1734
# Epoch 34/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4751.4316 - mean_absolute_error: 57.4286 - val_loss: 9674.3594 - val_mean_absolute_error: 95.8967
# Epoch 35/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4821.3223 - mean_absolute_error: 58.1007 - val_loss: 7210.8853 - val_mean_absolute_error: 82.5368
# Epoch 36/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4650.2241 - mean_absolute_error: 56.7624 - val_loss: 8412.1602 - val_mean_absolute_error: 89.4202
# Epoch 37/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4733.4121 - mean_absolute_error: 57.3986 - val_loss: 8095.2407 - val_mean_absolute_error: 87.6131
# Epoch 38/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4611.5986 - mean_absolute_error: 56.8580 - val_loss: 8878.5254 - val_mean_absolute_error: 92.0189
# Epoch 39/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4557.3550 - mean_absolute_error: 56.6147 - val_loss: 8520.6699 - val_mean_absolute_error: 89.8515
# Epoch 40/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4562.4946 - mean_absolute_error: 56.3374 - val_loss: 10003.0645 - val_mean_absolute_error: 97.8237
# Epoch 41/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4602.6665 - mean_absolute_error: 56.6757 - val_loss: 10272.8438 - val_mean_absolute_error: 99.2430
# Epoch 42/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4576.6836 - mean_absolute_error: 56.8306 - val_loss: 8323.6855 - val_mean_absolute_error: 88.8504
# Epoch 43/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4446.8574 - mean_absolute_error: 55.4494 - val_loss: 6761.3511 - val_mean_absolute_error: 77.9552
# Epoch 44/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4542.9634 - mean_absolute_error: 56.0788 - val_loss: 8314.8340 - val_mean_absolute_error: 88.8589
# Epoch 45/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4758.3374 - mean_absolute_error: 57.7251 - val_loss: 10335.6572 - val_mean_absolute_error: 99.4686
# Epoch 46/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4664.1128 - mean_absolute_error: 57.2172 - val_loss: 6387.4795 - val_mean_absolute_error: 77.4692
# Epoch 47/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4724.2515 - mean_absolute_error: 57.5773 - val_loss: 9770.8154 - val_mean_absolute_error: 96.6803
# Epoch 48/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4610.7378 - mean_absolute_error: 56.7030 - val_loss: 8340.3691 - val_mean_absolute_error: 88.7557
# Epoch 49/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4619.5181 - mean_absolute_error: 57.0254 - val_loss: 9532.2129 - val_mean_absolute_error: 95.5411
# Epoch 50/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4564.3296 - mean_absolute_error: 56.4587 - val_loss: 9073.7480 - val_mean_absolute_error: 92.3847
# Epoch 51/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4602.6113 - mean_absolute_error: 56.9642 - val_loss: 11232.7783 - val_mean_absolute_error: 103.8978
# Epoch 52/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4836.8730 - mean_absolute_error: 58.0244 - val_loss: 8558.4160 - val_mean_absolute_error: 90.3120
# Epoch 53/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4642.5508 - mean_absolute_error: 57.2346 - val_loss: 9546.9678 - val_mean_absolute_error: 95.6085
# Epoch 54/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4521.6006 - mean_absolute_error: 56.3531 - val_loss: 9986.1992 - val_mean_absolute_error: 97.9209
# Epoch 55/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4597.0205 - mean_absolute_error: 56.9449 - val_loss: 8191.4712 - val_mean_absolute_error: 88.2638
# Epoch 56/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4702.2920 - mean_absolute_error: 57.0405 - val_loss: 8257.2295 - val_mean_absolute_error: 88.5149
# Epoch 57/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4693.1147 - mean_absolute_error: 57.7161 - val_loss: 9484.0527 - val_mean_absolute_error: 95.3359
# Epoch 58/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4697.1479 - mean_absolute_error: 57.6345 - val_loss: 5998.8745 - val_mean_absolute_error: 73.9215
# Epoch 59/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5135.3687 - mean_absolute_error: 59.4476 - val_loss: 4729.5059 - val_mean_absolute_error: 65.8510
# Epoch 60/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4635.9604 - mean_absolute_error: 56.7694 - val_loss: 9494.7764 - val_mean_absolute_error: 95.0848
# Epoch 61/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4550.4497 - mean_absolute_error: 56.4392 - val_loss: 10873.7080 - val_mean_absolute_error: 102.2671
# Epoch 62/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4750.3477 - mean_absolute_error: 57.6797 - val_loss: 10813.6924 - val_mean_absolute_error: 102.0377
# Epoch 63/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4376.6064 - mean_absolute_error: 55.2276 - val_loss: 9225.2324 - val_mean_absolute_error: 93.9926
# Epoch 64/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4448.0586 - mean_absolute_error: 56.1354 - val_loss: 10885.6846 - val_mean_absolute_error: 102.4127
# Epoch 65/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4550.4878 - mean_absolute_error: 56.7448 - val_loss: 9993.5635 - val_mean_absolute_error: 97.9722
# Epoch 66/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4444.2842 - mean_absolute_error: 55.7893 - val_loss: 9303.3643 - val_mean_absolute_error: 94.4615
# Epoch 67/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4670.4937 - mean_absolute_error: 57.3919 - val_loss: 8993.5615 - val_mean_absolute_error: 92.8422
# Epoch 68/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4468.0742 - mean_absolute_error: 55.7751 - val_loss: 3979.6414 - val_mean_absolute_error: 59.0939
# Epoch 69/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4933.5068 - mean_absolute_error: 58.7161 - val_loss: 8059.0518 - val_mean_absolute_error: 87.4910
# Epoch 70/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4579.4526 - mean_absolute_error: 56.7993 - val_loss: 8078.2524 - val_mean_absolute_error: 87.8992
# Epoch 71/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4662.7031 - mean_absolute_error: 57.3788 - val_loss: 11329.7246 - val_mean_absolute_error: 104.5074
# Epoch 72/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4718.6392 - mean_absolute_error: 57.4615 - val_loss: 8103.1763 - val_mean_absolute_error: 87.9585
# Epoch 73/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4496.8472 - mean_absolute_error: 56.2963 - val_loss: 10841.8574 - val_mean_absolute_error: 102.2456
# Epoch 74/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4268.1558 - mean_absolute_error: 54.8456 - val_loss: 11363.3232 - val_mean_absolute_error: 104.7448
# Epoch 75/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4438.9429 - mean_absolute_error: 55.5888 - val_loss: 8540.7324 - val_mean_absolute_error: 90.4402
# Epoch 76/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4345.1699 - mean_absolute_error: 55.2440 - val_loss: 11173.1631 - val_mean_absolute_error: 103.8412
# Epoch 77/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4487.8208 - mean_absolute_error: 56.3431 - val_loss: 6993.0254 - val_mean_absolute_error: 81.2785
# Epoch 78/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4684.9014 - mean_absolute_error: 57.3140 - val_loss: 11721.5254 - val_mean_absolute_error: 106.4279
# Epoch 79/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4471.8779 - mean_absolute_error: 55.6449 - val_loss: 10426.8428 - val_mean_absolute_error: 100.2156
# Epoch 80/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4599.1968 - mean_absolute_error: 56.7434 - val_loss: 11775.0967 - val_mean_absolute_error: 106.6519
# Epoch 81/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4378.1587 - mean_absolute_error: 55.3861 - val_loss: 12452.4932 - val_mean_absolute_error: 109.7763
# Epoch 82/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4372.9092 - mean_absolute_error: 55.4593 - val_loss: 10620.1250 - val_mean_absolute_error: 101.0392
# Epoch 83/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4312.9463 - mean_absolute_error: 55.1824 - val_loss: 11409.1006 - val_mean_absolute_error: 104.8930
# Epoch 84/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4316.4976 - mean_absolute_error: 55.2101 - val_loss: 6620.6377 - val_mean_absolute_error: 79.1358
# Epoch 85/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4714.4199 - mean_absolute_error: 57.8034 - val_loss: 10027.6299 - val_mean_absolute_error: 98.2268
# Epoch 86/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4394.7793 - mean_absolute_error: 55.5652 - val_loss: 8204.0234 - val_mean_absolute_error: 88.5829
# Epoch 87/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4742.7866 - mean_absolute_error: 57.8924 - val_loss: 11060.4297 - val_mean_absolute_error: 103.3174
# Epoch 88/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4434.7866 - mean_absolute_error: 55.9925 - val_loss: 6022.3101 - val_mean_absolute_error: 75.1519
# Epoch 89/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4653.4600 - mean_absolute_error: 57.1543 - val_loss: 10265.8857 - val_mean_absolute_error: 99.3955
# Epoch 90/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4379.7715 - mean_absolute_error: 55.2537 - val_loss: 10501.2246 - val_mean_absolute_error: 100.6003
# Epoch 91/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4590.8301 - mean_absolute_error: 56.7947 - val_loss: 11450.0801 - val_mean_absolute_error: 105.1034
# Epoch 92/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4278.2505 - mean_absolute_error: 55.3480 - val_loss: 11572.2129 - val_mean_absolute_error: 105.7132
# Epoch 93/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4356.0000 - mean_absolute_error: 55.3370 - val_loss: 9920.7178 - val_mean_absolute_error: 97.6997
# Epoch 94/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4544.9941 - mean_absolute_error: 56.4165 - val_loss: 9003.1064 - val_mean_absolute_error: 92.8253
# Epoch 95/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4271.4321 - mean_absolute_error: 55.0842 - val_loss: 9257.5850 - val_mean_absolute_error: 94.3437
# Epoch 96/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4314.7441 - mean_absolute_error: 55.0162 - val_loss: 9051.5127 - val_mean_absolute_error: 93.2122
# Epoch 97/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4370.5322 - mean_absolute_error: 55.6304 - val_loss: 10873.8506 - val_mean_absolute_error: 102.5044
# Epoch 98/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4400.3872 - mean_absolute_error: 55.5788 - val_loss: 10619.1377 - val_mean_absolute_error: 101.1165
# Epoch 99/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4243.3970 - mean_absolute_error: 54.9965 - val_loss: 7568.8291 - val_mean_absolute_error: 85.0009
# Epoch 100/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4452.1235 - mean_absolute_error: 55.8424 - val_loss: 9819.8398 - val_mean_absolute_error: 97.2515
# Epoch 101/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4252.5967 - mean_absolute_error: 54.8626 - val_loss: 10689.3213 - val_mean_absolute_error: 101.5977
# Epoch 102/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4407.0317 - mean_absolute_error: 55.4104 - val_loss: 8479.0020 - val_mean_absolute_error: 90.1287
# Epoch 103/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4416.3711 - mean_absolute_error: 56.1247 - val_loss: 11657.9746 - val_mean_absolute_error: 106.2074
# Epoch 104/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4379.3320 - mean_absolute_error: 55.8224 - val_loss: 11941.4883 - val_mean_absolute_error: 107.3693
# Epoch 105/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4420.7354 - mean_absolute_error: 55.9945 - val_loss: 7883.7397 - val_mean_absolute_error: 86.8511
# Epoch 106/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4259.9087 - mean_absolute_error: 54.8244 - val_loss: 11733.1230 - val_mean_absolute_error: 106.5574
# Epoch 107/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4294.7935 - mean_absolute_error: 55.0556 - val_loss: 8696.3037 - val_mean_absolute_error: 91.2740
# Epoch 108/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4495.0449 - mean_absolute_error: 56.8163 - val_loss: 10904.3965 - val_mean_absolute_error: 102.6490
# Epoch 109/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4321.1045 - mean_absolute_error: 55.5537 - val_loss: 12219.8594 - val_mean_absolute_error: 108.8002
# Epoch 110/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4438.7207 - mean_absolute_error: 55.8372 - val_loss: 10956.5449 - val_mean_absolute_error: 102.8756
# Epoch 111/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4306.5039 - mean_absolute_error: 54.9026 - val_loss: 12188.3037 - val_mean_absolute_error: 108.6490
# Epoch 112/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4235.2104 - mean_absolute_error: 55.0676 - val_loss: 9538.0537 - val_mean_absolute_error: 95.8007
# Epoch 113/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4309.1880 - mean_absolute_error: 55.0355 - val_loss: 9140.7236 - val_mean_absolute_error: 93.7232
# Epoch 114/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4194.8774 - mean_absolute_error: 54.6462 - val_loss: 12713.5713 - val_mean_absolute_error: 111.0220
# Epoch 115/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4379.6206 - mean_absolute_error: 55.6120 - val_loss: 13112.1885 - val_mean_absolute_error: 112.7573
# Epoch 116/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4312.5708 - mean_absolute_error: 55.2026 - val_loss: 12448.2217 - val_mean_absolute_error: 109.8171
# Epoch 117/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4396.9121 - mean_absolute_error: 55.8995 - val_loss: 10854.0400 - val_mean_absolute_error: 102.3978
# Epoch 118/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4223.8101 - mean_absolute_error: 54.4143 - val_loss: 9988.3135 - val_mean_absolute_error: 98.1115
# Epoch 119/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4283.0254 - mean_absolute_error: 55.2068 - val_loss: 10241.6660 - val_mean_absolute_error: 99.3698
# Epoch 120/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4132.4111 - mean_absolute_error: 54.1833 - val_loss: 9565.8438 - val_mean_absolute_error: 95.9098
# Epoch 121/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4197.2817 - mean_absolute_error: 54.6414 - val_loss: 9075.7686 - val_mean_absolute_error: 93.3618
# Epoch 122/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4282.6504 - mean_absolute_error: 54.9483 - val_loss: 13244.3975 - val_mean_absolute_error: 113.3508
# Epoch 123/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4529.2373 - mean_absolute_error: 56.5215 - val_loss: 9588.1143 - val_mean_absolute_error: 96.0226
# Epoch 124/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4267.1353 - mean_absolute_error: 54.9430 - val_loss: 12625.1797 - val_mean_absolute_error: 110.6482
# Epoch 125/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4456.8921 - mean_absolute_error: 55.8951 - val_loss: 12671.6846 - val_mean_absolute_error: 110.8351
# Epoch 126/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4402.4917 - mean_absolute_error: 55.5980 - val_loss: 11596.6289 - val_mean_absolute_error: 105.9095
# Epoch 127/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4277.1089 - mean_absolute_error: 54.9247 - val_loss: 12095.5312 - val_mean_absolute_error: 108.2404
# Epoch 128/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4320.1421 - mean_absolute_error: 55.5035 - val_loss: 12164.5176 - val_mean_absolute_error: 108.5639
# Epoch 129/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4240.5059 - mean_absolute_error: 54.8959 - val_loss: 13619.4678 - val_mean_absolute_error: 114.9802
# Epoch 130/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4426.1318 - mean_absolute_error: 55.6374 - val_loss: 11655.0869 - val_mean_absolute_error: 106.1920
# Epoch 131/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4357.6855 - mean_absolute_error: 55.3809 - val_loss: 11555.9629 - val_mean_absolute_error: 105.7697
# Epoch 132/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4239.4863 - mean_absolute_error: 55.1089 - val_loss: 13016.8242 - val_mean_absolute_error: 112.3785
# Epoch 133/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4383.5723 - mean_absolute_error: 55.6689 - val_loss: 11857.4336 - val_mean_absolute_error: 107.1674
# Epoch 134/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4441.7725 - mean_absolute_error: 56.1698 - val_loss: 11734.6299 - val_mean_absolute_error: 106.5915
# Epoch 135/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4422.4746 - mean_absolute_error: 56.3060 - val_loss: 12083.8613 - val_mean_absolute_error: 108.1883
# Epoch 136/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4186.4087 - mean_absolute_error: 54.3820 - val_loss: 11985.9346 - val_mean_absolute_error: 107.7550
# Epoch 137/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4209.4097 - mean_absolute_error: 54.8259 - val_loss: 11596.9736 - val_mean_absolute_error: 105.9256
# Epoch 138/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4137.0576 - mean_absolute_error: 54.0267 - val_loss: 9980.8975 - val_mean_absolute_error: 98.0358
# Epoch 139/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4160.6538 - mean_absolute_error: 54.1852 - val_loss: 11442.6338 - val_mean_absolute_error: 105.2007
# Epoch 140/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4452.6572 - mean_absolute_error: 55.9868 - val_loss: 9105.6875 - val_mean_absolute_error: 93.5387
# Epoch 141/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4278.1660 - mean_absolute_error: 55.0471 - val_loss: 12843.2178 - val_mean_absolute_error: 111.6009
# Epoch 142/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4398.2319 - mean_absolute_error: 55.7235 - val_loss: 11634.1738 - val_mean_absolute_error: 106.1113
# Epoch 143/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4195.1738 - mean_absolute_error: 54.1953 - val_loss: 11426.2480 - val_mean_absolute_error: 105.1364
# Epoch 144/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4422.7720 - mean_absolute_error: 56.2420 - val_loss: 10741.8350 - val_mean_absolute_error: 101.8804
# Epoch 145/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4219.2725 - mean_absolute_error: 55.0155 - val_loss: 10402.3633 - val_mean_absolute_error: 100.2055
# Epoch 146/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4209.4951 - mean_absolute_error: 54.7970 - val_loss: 10325.4990 - val_mean_absolute_error: 99.8341
# Epoch 147/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4213.4219 - mean_absolute_error: 54.8389 - val_loss: 13253.8301 - val_mean_absolute_error: 113.4381
# Epoch 148/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4265.2319 - mean_absolute_error: 55.0381 - val_loss: 10516.6758 - val_mean_absolute_error: 100.7772
# Epoch 149/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4319.4146 - mean_absolute_error: 55.6304 - val_loss: 11264.1377 - val_mean_absolute_error: 104.3894
# Epoch 150/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4213.3345 - mean_absolute_error: 54.6771 - val_loss: 12584.5596 - val_mean_absolute_error: 110.4594
# Epoch 151/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4319.4663 - mean_absolute_error: 55.5310 - val_loss: 12696.5742 - val_mean_absolute_error: 110.9541
# Epoch 152/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4225.0698 - mean_absolute_error: 54.8701 - val_loss: 10584.0645 - val_mean_absolute_error: 101.1304
# Epoch 153/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4382.3418 - mean_absolute_error: 55.7331 - val_loss: 11671.6406 - val_mean_absolute_error: 106.2913
# Epoch 154/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4395.8989 - mean_absolute_error: 56.2330 - val_loss: 9376.1514 - val_mean_absolute_error: 94.9545
# Epoch 155/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4402.1719 - mean_absolute_error: 55.9015 - val_loss: 9127.7432 - val_mean_absolute_error: 93.6638
# Epoch 156/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4323.4209 - mean_absolute_error: 55.4366 - val_loss: 11378.7100 - val_mean_absolute_error: 104.9021
# Epoch 157/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4288.0474 - mean_absolute_error: 55.1222 - val_loss: 12705.3174 - val_mean_absolute_error: 110.9878
# Epoch 158/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4302.7256 - mean_absolute_error: 55.0939 - val_loss: 12475.7451 - val_mean_absolute_error: 109.9693
# Epoch 159/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4369.0542 - mean_absolute_error: 55.8126 - val_loss: 13590.8506 - val_mean_absolute_error: 114.8585
# Epoch 160/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4519.4609 - mean_absolute_error: 56.7246 - val_loss: 8187.4312 - val_mean_absolute_error: 88.6000
# Epoch 161/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4116.6587 - mean_absolute_error: 53.8530 - val_loss: 12380.0938 - val_mean_absolute_error: 109.5655
# Epoch 162/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4291.2842 - mean_absolute_error: 55.2042 - val_loss: 11217.7129 - val_mean_absolute_error: 104.1926
# Epoch 163/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4198.9731 - mean_absolute_error: 54.4255 - val_loss: 10324.6982 - val_mean_absolute_error: 99.8642
# Epoch 164/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4205.3545 - mean_absolute_error: 54.7475 - val_loss: 11318.8574 - val_mean_absolute_error: 104.6721
# Epoch 165/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4299.5566 - mean_absolute_error: 55.2581 - val_loss: 12558.3535 - val_mean_absolute_error: 110.3599
# Epoch 166/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4245.9404 - mean_absolute_error: 54.9309 - val_loss: 11740.7783 - val_mean_absolute_error: 106.6626
# Epoch 167/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4261.1914 - mean_absolute_error: 55.4818 - val_loss: 10627.9785 - val_mean_absolute_error: 101.3258
# Epoch 168/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4155.1416 - mean_absolute_error: 54.1186 - val_loss: 12634.6973 - val_mean_absolute_error: 110.6961
# Epoch 169/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4122.5605 - mean_absolute_error: 54.0867 - val_loss: 11887.3213 - val_mean_absolute_error: 107.3098
# Epoch 170/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4271.7803 - mean_absolute_error: 54.5470 - val_loss: 11748.3867 - val_mean_absolute_error: 106.6381
# Epoch 171/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4321.2974 - mean_absolute_error: 55.3768 - val_loss: 10637.8076 - val_mean_absolute_error: 101.3813
# Epoch 172/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4266.9922 - mean_absolute_error: 54.5480 - val_loss: 11902.0947 - val_mean_absolute_error: 107.3917
# Epoch 173/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4164.2769 - mean_absolute_error: 54.4492 - val_loss: 6684.1416 - val_mean_absolute_error: 79.4344
# Epoch 174/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4499.7520 - mean_absolute_error: 56.5976 - val_loss: 7204.8511 - val_mean_absolute_error: 82.8621
# Epoch 175/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4661.3643 - mean_absolute_error: 57.2636 - val_loss: 11984.4697 - val_mean_absolute_error: 107.7185
# Epoch 176/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4287.6709 - mean_absolute_error: 54.9558 - val_loss: 11448.0410 - val_mean_absolute_error: 105.2804
# Epoch 177/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4271.6929 - mean_absolute_error: 55.5463 - val_loss: 11484.3330 - val_mean_absolute_error: 105.4813
# Epoch 178/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4157.0552 - mean_absolute_error: 54.1384 - val_loss: 12592.2842 - val_mean_absolute_error: 110.5410
# Epoch 179/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4374.1562 - mean_absolute_error: 56.1287 - val_loss: 8191.3936 - val_mean_absolute_error: 88.5662
# Epoch 180/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4340.7832 - mean_absolute_error: 55.5774 - val_loss: 11796.7246 - val_mean_absolute_error: 106.9138
# Epoch 181/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4157.6367 - mean_absolute_error: 53.9567 - val_loss: 13615.2646 - val_mean_absolute_error: 115.0193
# Epoch 182/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4477.7759 - mean_absolute_error: 56.3695 - val_loss: 12923.1494 - val_mean_absolute_error: 111.9983
# Epoch 183/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4336.6304 - mean_absolute_error: 55.2700 - val_loss: 11730.3936 - val_mean_absolute_error: 106.5993
# Epoch 184/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4496.5610 - mean_absolute_error: 56.8093 - val_loss: 11408.7725 - val_mean_absolute_error: 105.0952
# Epoch 185/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4277.1831 - mean_absolute_error: 55.3110 - val_loss: 13972.3301 - val_mean_absolute_error: 116.5378
# Epoch 186/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4358.5762 - mean_absolute_error: 55.6099 - val_loss: 12807.2559 - val_mean_absolute_error: 111.4590
# Epoch 187/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4035.2966 - mean_absolute_error: 53.4874 - val_loss: 13165.6660 - val_mean_absolute_error: 113.0619
# Epoch 188/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4337.1855 - mean_absolute_error: 55.7155 - val_loss: 12714.2344 - val_mean_absolute_error: 111.0650
# Epoch 189/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4303.8247 - mean_absolute_error: 55.4465 - val_loss: 13078.8115 - val_mean_absolute_error: 112.6858
# Epoch 190/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4235.5469 - mean_absolute_error: 54.7070 - val_loss: 13230.5684 - val_mean_absolute_error: 113.3234
# Epoch 191/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4435.8848 - mean_absolute_error: 55.7818 - val_loss: 12726.9561 - val_mean_absolute_error: 111.0705
# Epoch 192/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4602.1899 - mean_absolute_error: 57.0007 - val_loss: 11624.8398 - val_mean_absolute_error: 106.1330
# Epoch 193/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4127.8169 - mean_absolute_error: 54.0933 - val_loss: 11612.4727 - val_mean_absolute_error: 106.0714
# Epoch 194/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4118.9087 - mean_absolute_error: 54.1067 - val_loss: 10789.2871 - val_mean_absolute_error: 102.1307
# Epoch 195/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4301.6274 - mean_absolute_error: 55.2943 - val_loss: 11260.4268 - val_mean_absolute_error: 104.4052
# Epoch 196/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4231.1250 - mean_absolute_error: 54.7207 - val_loss: 9350.1035 - val_mean_absolute_error: 94.8532
# Epoch 197/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4467.7749 - mean_absolute_error: 56.2651 - val_loss: 9825.1104 - val_mean_absolute_error: 97.3527
# Epoch 198/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4317.7842 - mean_absolute_error: 55.3555 - val_loss: 11719.8350 - val_mean_absolute_error: 106.5786
# Epoch 199/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4140.9180 - mean_absolute_error: 54.1939 - val_loss: 8485.6221 - val_mean_absolute_error: 90.1764
# Epoch 200/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4386.7314 - mean_absolute_error: 55.8388 - val_loss: 11822.6846 - val_mean_absolute_error: 107.0502
# Epoch 201/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4242.3599 - mean_absolute_error: 55.1221 - val_loss: 12009.1494 - val_mean_absolute_error: 107.9217
# Epoch 202/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4108.4492 - mean_absolute_error: 54.0661 - val_loss: 9033.3311 - val_mean_absolute_error: 93.0725
# Epoch 203/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4329.8672 - mean_absolute_error: 55.3732 - val_loss: 10787.7822 - val_mean_absolute_error: 102.1317
# Epoch 204/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4156.3398 - mean_absolute_error: 54.2736 - val_loss: 9907.0312 - val_mean_absolute_error: 97.7625
# Epoch 205/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4241.7642 - mean_absolute_error: 55.0648 - val_loss: 13369.7021 - val_mean_absolute_error: 113.9841
# Epoch 206/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4162.4873 - mean_absolute_error: 54.2997 - val_loss: 10359.5830 - val_mean_absolute_error: 100.0259
# Epoch 207/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4276.4546 - mean_absolute_error: 55.1398 - val_loss: 13483.4941 - val_mean_absolute_error: 114.4666
# Epoch 208/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4205.3052 - mean_absolute_error: 54.8903 - val_loss: 7986.8647 - val_mean_absolute_error: 87.3135
# Epoch 209/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4429.6821 - mean_absolute_error: 56.2583 - val_loss: 12586.7383 - val_mean_absolute_error: 110.5178
# Epoch 210/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4153.8198 - mean_absolute_error: 54.5783 - val_loss: 8264.6064 - val_mean_absolute_error: 88.7774
# Epoch 211/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4298.1401 - mean_absolute_error: 55.3003 - val_loss: 9806.4580 - val_mean_absolute_error: 97.2357
# Epoch 212/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4278.3608 - mean_absolute_error: 55.1044 - val_loss: 13764.5635 - val_mean_absolute_error: 115.6655
# Epoch 213/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4378.8447 - mean_absolute_error: 55.5361 - val_loss: 11797.4453 - val_mean_absolute_error: 106.9483
# Epoch 214/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4383.1602 - mean_absolute_error: 55.6213 - val_loss: 9164.6523 - val_mean_absolute_error: 93.9586
# Epoch 215/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4259.5049 - mean_absolute_error: 55.3438 - val_loss: 11862.0254 - val_mean_absolute_error: 107.2567
# Epoch 216/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4092.2083 - mean_absolute_error: 53.8524 - val_loss: 10512.6367 - val_mean_absolute_error: 100.8071
# Epoch 217/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4200.6172 - mean_absolute_error: 54.7146 - val_loss: 9625.6133 - val_mean_absolute_error: 96.2933
# Epoch 218/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4364.9121 - mean_absolute_error: 55.3362 - val_loss: 12522.7041 - val_mean_absolute_error: 110.2584
# Epoch 219/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4390.5127 - mean_absolute_error: 56.0314 - val_loss: 11657.0137 - val_mean_absolute_error: 106.2895
# Epoch 220/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4293.0093 - mean_absolute_error: 55.3389 - val_loss: 9761.2178 - val_mean_absolute_error: 96.8379
# Epoch 221/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4380.8252 - mean_absolute_error: 56.0729 - val_loss: 11025.9541 - val_mean_absolute_error: 103.3150
# Epoch 222/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4283.3022 - mean_absolute_error: 55.5977 - val_loss: 8802.3770 - val_mean_absolute_error: 91.9628
# Epoch 223/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4401.5039 - mean_absolute_error: 55.7536 - val_loss: 9243.5654 - val_mean_absolute_error: 94.3463
# Epoch 224/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4201.6475 - mean_absolute_error: 54.5257 - val_loss: 11862.5479 - val_mean_absolute_error: 107.2392
# Epoch 225/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4184.5752 - mean_absolute_error: 54.4134 - val_loss: 10340.7539 - val_mean_absolute_error: 99.9512
# Epoch 226/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4266.3906 - mean_absolute_error: 54.9473 - val_loss: 10519.6396 - val_mean_absolute_error: 100.8447
# Epoch 227/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4325.6631 - mean_absolute_error: 55.7609 - val_loss: 10692.3174 - val_mean_absolute_error: 101.6764
# Epoch 228/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4130.1162 - mean_absolute_error: 54.1786 - val_loss: 13010.9688 - val_mean_absolute_error: 112.4140
# Epoch 229/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4278.3101 - mean_absolute_error: 55.0846 - val_loss: 12064.6963 - val_mean_absolute_error: 108.1615
# Epoch 230/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4278.9502 - mean_absolute_error: 55.3601 - val_loss: 11744.9414 - val_mean_absolute_error: 106.6927
# Epoch 231/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4293.8452 - mean_absolute_error: 55.5762 - val_loss: 9518.4629 - val_mean_absolute_error: 95.8338
# Epoch 232/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4324.6973 - mean_absolute_error: 55.5372 - val_loss: 11062.2773 - val_mean_absolute_error: 103.4842
# Epoch 233/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4376.5479 - mean_absolute_error: 55.8095 - val_loss: 11981.0225 - val_mean_absolute_error: 107.8005
# Epoch 234/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4193.0498 - mean_absolute_error: 54.5372 - val_loss: 14277.1914 - val_mean_absolute_error: 117.8439
# Epoch 235/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4298.2251 - mean_absolute_error: 55.2873 - val_loss: 10631.3223 - val_mean_absolute_error: 101.3677
# Epoch 236/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4214.6616 - mean_absolute_error: 54.1617 - val_loss: 8775.1182 - val_mean_absolute_error: 91.8957
# Epoch 237/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4174.5791 - mean_absolute_error: 54.1202 - val_loss: 10122.2588 - val_mean_absolute_error: 98.8475
# Epoch 238/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4538.3369 - mean_absolute_error: 56.3889 - val_loss: 12184.2285 - val_mean_absolute_error: 108.6336
# Epoch 239/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4127.7246 - mean_absolute_error: 54.0671 - val_loss: 12683.3398 - val_mean_absolute_error: 110.9455
# Epoch 240/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4152.4043 - mean_absolute_error: 54.5623 - val_loss: 13277.3789 - val_mean_absolute_error: 113.5759
# Epoch 241/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4260.4365 - mean_absolute_error: 55.4955 - val_loss: 11233.3809 - val_mean_absolute_error: 104.3022
# Epoch 242/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4255.6021 - mean_absolute_error: 55.1178 - val_loss: 14708.4648 - val_mean_absolute_error: 119.6425
# Epoch 243/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4573.5215 - mean_absolute_error: 57.2746 - val_loss: 14145.0322 - val_mean_absolute_error: 117.2963
# Epoch 244/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4362.5752 - mean_absolute_error: 55.3432 - val_loss: 10644.8027 - val_mean_absolute_error: 101.4063
# Epoch 245/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4197.4277 - mean_absolute_error: 54.3661 - val_loss: 9646.3271 - val_mean_absolute_error: 96.4074
# Epoch 246/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4336.9800 - mean_absolute_error: 55.8761 - val_loss: 12105.5615 - val_mean_absolute_error: 108.3712
# Epoch 247/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4108.5996 - mean_absolute_error: 54.3633 - val_loss: 14158.3574 - val_mean_absolute_error: 117.3568
# Epoch 248/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4251.9541 - mean_absolute_error: 55.1610 - val_loss: 14755.1045 - val_mean_absolute_error: 119.8508
# Epoch 249/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4317.9678 - mean_absolute_error: 55.1306 - val_loss: 8866.0713 - val_mean_absolute_error: 92.2770
# Epoch 250/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4130.4321 - mean_absolute_error: 54.0695 - val_loss: 13961.9316 - val_mean_absolute_error: 116.5306
# Epoch 251/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4238.0332 - mean_absolute_error: 55.0303 - val_loss: 12367.8262 - val_mean_absolute_error: 109.5414
# Epoch 252/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4271.7271 - mean_absolute_error: 55.0416 - val_loss: 13989.4688 - val_mean_absolute_error: 116.6441
# Epoch 253/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4356.8096 - mean_absolute_error: 55.8060 - val_loss: 11738.5010 - val_mean_absolute_error: 106.6552
# Epoch 254/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4235.3833 - mean_absolute_error: 55.0930 - val_loss: 13881.1641 - val_mean_absolute_error: 116.1773
# Epoch 255/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4246.3154 - mean_absolute_error: 54.9696 - val_loss: 13057.8809 - val_mean_absolute_error: 112.6129
# Epoch 256/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4349.8613 - mean_absolute_error: 55.7065 - val_loss: 12846.7832 - val_mean_absolute_error: 111.6795
# Epoch 257/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4235.4702 - mean_absolute_error: 55.0862 - val_loss: 12911.0195 - val_mean_absolute_error: 111.9812
# Epoch 258/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4100.4683 - mean_absolute_error: 53.9531 - val_loss: 14187.9229 - val_mean_absolute_error: 117.4999
# Epoch 259/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4388.0171 - mean_absolute_error: 56.2119 - val_loss: 10482.9365 - val_mean_absolute_error: 100.6348
# Epoch 260/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4192.9297 - mean_absolute_error: 54.6841 - val_loss: 10916.6328 - val_mean_absolute_error: 102.7966
# Epoch 261/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4112.8022 - mean_absolute_error: 54.2820 - val_loss: 11617.9590 - val_mean_absolute_error: 106.1141
# Epoch 262/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4135.0981 - mean_absolute_error: 54.1184 - val_loss: 11224.3994 - val_mean_absolute_error: 104.2329
# Epoch 263/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4300.3716 - mean_absolute_error: 55.3208 - val_loss: 10264.2627 - val_mean_absolute_error: 99.6081
# Epoch 264/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4223.6382 - mean_absolute_error: 54.8474 - val_loss: 14429.1035 - val_mean_absolute_error: 118.5013
# Epoch 265/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4260.0625 - mean_absolute_error: 54.9744 - val_loss: 13071.0039 - val_mean_absolute_error: 112.6754
# Epoch 266/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4108.9526 - mean_absolute_error: 53.9371 - val_loss: 12627.2910 - val_mean_absolute_error: 110.7203
# Epoch 267/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4083.5203 - mean_absolute_error: 53.8579 - val_loss: 11558.9814 - val_mean_absolute_error: 105.8424
# Epoch 268/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4223.5410 - mean_absolute_error: 54.7513 - val_loss: 9583.0000 - val_mean_absolute_error: 96.1104
# Epoch 269/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4171.3965 - mean_absolute_error: 54.2747 - val_loss: 13586.8926 - val_mean_absolute_error: 114.9216
# Epoch 270/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4265.0508 - mean_absolute_error: 55.3556 - val_loss: 13205.4219 - val_mean_absolute_error: 113.2794
# Epoch 271/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4459.3481 - mean_absolute_error: 56.3006 - val_loss: 11571.9199 - val_mean_absolute_error: 105.9040
# Epoch 272/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4205.5488 - mean_absolute_error: 54.4947 - val_loss: 12923.3154 - val_mean_absolute_error: 112.0254
# Epoch 273/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4386.0513 - mean_absolute_error: 56.2032 - val_loss: 9839.8477 - val_mean_absolute_error: 97.3446
# Epoch 274/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4292.8057 - mean_absolute_error: 55.2772 - val_loss: 13174.9160 - val_mean_absolute_error: 113.1268
# Epoch 275/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4261.7896 - mean_absolute_error: 55.3681 - val_loss: 7270.9336 - val_mean_absolute_error: 83.2598
# Epoch 276/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4255.9082 - mean_absolute_error: 54.7559 - val_loss: 10047.0596 - val_mean_absolute_error: 98.4470
# Epoch 277/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4369.8525 - mean_absolute_error: 55.8978 - val_loss: 12825.3066 - val_mean_absolute_error: 111.6115
# Epoch 278/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4076.2212 - mean_absolute_error: 54.2209 - val_loss: 12463.7754 - val_mean_absolute_error: 110.0070
# Epoch 279/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4142.8105 - mean_absolute_error: 54.4729 - val_loss: 7809.8691 - val_mean_absolute_error: 86.3100
# Epoch 280/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4603.2212 - mean_absolute_error: 56.7662 - val_loss: 11641.5605 - val_mean_absolute_error: 106.2229
# Epoch 281/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4301.6729 - mean_absolute_error: 55.5172 - val_loss: 9525.8643 - val_mean_absolute_error: 95.7923
# Epoch 282/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4180.2852 - mean_absolute_error: 54.4791 - val_loss: 11833.1650 - val_mean_absolute_error: 107.1351
# Epoch 283/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4175.7729 - mean_absolute_error: 54.5859 - val_loss: 13051.0635 - val_mean_absolute_error: 112.6210
# Epoch 284/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4157.2642 - mean_absolute_error: 54.3400 - val_loss: 12387.1328 - val_mean_absolute_error: 109.7064
# Epoch 285/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4363.2002 - mean_absolute_error: 55.6956 - val_loss: 9080.5771 - val_mean_absolute_error: 93.5344
# Epoch 286/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4133.4238 - mean_absolute_error: 54.3597 - val_loss: 11567.1211 - val_mean_absolute_error: 105.9074
# Epoch 287/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4520.0083 - mean_absolute_error: 56.8239 - val_loss: 10002.5273 - val_mean_absolute_error: 98.3062
# Epoch 288/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4210.5923 - mean_absolute_error: 54.8957 - val_loss: 9134.7197 - val_mean_absolute_error: 93.8275
# Epoch 289/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4271.1372 - mean_absolute_error: 55.0494 - val_loss: 11476.8379 - val_mean_absolute_error: 105.5000
# Epoch 290/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4208.3403 - mean_absolute_error: 54.8355 - val_loss: 13466.8613 - val_mean_absolute_error: 114.4492
# Epoch 291/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4178.0981 - mean_absolute_error: 54.7373 - val_loss: 9177.8369 - val_mean_absolute_error: 93.9472
# Epoch 292/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4308.3447 - mean_absolute_error: 55.4313 - val_loss: 13202.8135 - val_mean_absolute_error: 113.3160
# Epoch 293/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4297.7041 - mean_absolute_error: 55.2008 - val_loss: 8671.6084 - val_mean_absolute_error: 91.3981
# Epoch 294/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4148.0723 - mean_absolute_error: 54.3203 - val_loss: 12242.2109 - val_mean_absolute_error: 108.9999
# Epoch 295/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4175.6455 - mean_absolute_error: 54.7773 - val_loss: 10672.5928 - val_mean_absolute_error: 101.6208
# Epoch 296/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4147.5801 - mean_absolute_error: 54.3506 - val_loss: 12806.0576 - val_mean_absolute_error: 111.5226
# Epoch 297/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4165.3804 - mean_absolute_error: 54.2680 - val_loss: 11532.3105 - val_mean_absolute_error: 105.7257
# Epoch 298/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4219.3057 - mean_absolute_error: 54.8641 - val_loss: 12997.8555 - val_mean_absolute_error: 112.4236
# Epoch 299/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4304.7646 - mean_absolute_error: 55.3205 - val_loss: 10285.4131 - val_mean_absolute_error: 99.7585
# Epoch 300/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4149.5620 - mean_absolute_error: 54.3301 - val_loss: 14063.3447 - val_mean_absolute_error: 116.9981
# Epoch 301/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4264.9238 - mean_absolute_error: 55.2816 - val_loss: 14191.9873 - val_mean_absolute_error: 117.5638
# Epoch 302/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4364.3184 - mean_absolute_error: 55.8062 - val_loss: 12853.0146 - val_mean_absolute_error: 111.7985
# Epoch 303/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4262.8174 - mean_absolute_error: 55.2596 - val_loss: 11834.7549 - val_mean_absolute_error: 107.1495
# Epoch 304/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4116.6738 - mean_absolute_error: 54.6077 - val_loss: 14077.9229 - val_mean_absolute_error: 117.0817
# Epoch 305/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4168.7549 - mean_absolute_error: 54.4780 - val_loss: 13723.8027 - val_mean_absolute_error: 115.5831
# Epoch 306/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4198.3799 - mean_absolute_error: 54.7569 - val_loss: 13549.4258 - val_mean_absolute_error: 114.8174
# Epoch 307/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4151.4033 - mean_absolute_error: 54.4129 - val_loss: 10052.2363 - val_mean_absolute_error: 98.5348
# Epoch 308/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4220.4390 - mean_absolute_error: 55.1677 - val_loss: 11620.2383 - val_mean_absolute_error: 106.2006
# Epoch 309/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4106.5986 - mean_absolute_error: 53.8676 - val_loss: 11338.5322 - val_mean_absolute_error: 104.8448
# Epoch 310/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4312.9224 - mean_absolute_error: 55.2985 - val_loss: 12276.6895 - val_mean_absolute_error: 109.1941
# Epoch 311/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4277.1191 - mean_absolute_error: 55.1809 - val_loss: 9152.9170 - val_mean_absolute_error: 93.9605
# Epoch 312/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4304.6284 - mean_absolute_error: 55.6654 - val_loss: 8752.8379 - val_mean_absolute_error: 91.7493
# Epoch 313/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4165.3276 - mean_absolute_error: 54.1899 - val_loss: 12935.7607 - val_mean_absolute_error: 112.1571
# Epoch 314/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4265.5166 - mean_absolute_error: 54.8757 - val_loss: 12519.9912 - val_mean_absolute_error: 110.3048
# Epoch 315/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4226.2354 - mean_absolute_error: 55.1987 - val_loss: 12227.8330 - val_mean_absolute_error: 108.9804
# Epoch 316/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4168.9966 - mean_absolute_error: 54.4536 - val_loss: 12593.7607 - val_mean_absolute_error: 110.6543
# Epoch 317/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4280.7632 - mean_absolute_error: 55.3387 - val_loss: 12401.3281 - val_mean_absolute_error: 109.7751
# Epoch 318/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4218.5288 - mean_absolute_error: 55.1017 - val_loss: 13529.4062 - val_mean_absolute_error: 114.7554
# Epoch 319/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4376.0640 - mean_absolute_error: 55.8432 - val_loss: 10552.0938 - val_mean_absolute_error: 101.0722
# Epoch 320/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4146.5732 - mean_absolute_error: 54.2642 - val_loss: 12314.6436 - val_mean_absolute_error: 109.3832
# Epoch 321/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3992.1477 - mean_absolute_error: 53.0544 - val_loss: 12023.0400 - val_mean_absolute_error: 108.0558
# Epoch 322/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4106.8721 - mean_absolute_error: 54.0374 - val_loss: 12698.1250 - val_mean_absolute_error: 111.1097
# Epoch 323/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4146.5317 - mean_absolute_error: 54.1347 - val_loss: 11587.5215 - val_mean_absolute_error: 106.0482
# Epoch 324/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4135.5752 - mean_absolute_error: 54.6649 - val_loss: 12311.4463 - val_mean_absolute_error: 109.3754
# Epoch 325/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4330.4487 - mean_absolute_error: 55.8147 - val_loss: 11207.0088 - val_mean_absolute_error: 104.2296
# Epoch 326/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4263.1909 - mean_absolute_error: 55.1370 - val_loss: 8983.3506 - val_mean_absolute_error: 92.8631
# Epoch 327/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4275.6226 - mean_absolute_error: 55.2466 - val_loss: 12668.5635 - val_mean_absolute_error: 110.9967
# Epoch 328/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4185.3467 - mean_absolute_error: 54.7031 - val_loss: 13600.6602 - val_mean_absolute_error: 115.0809
# Epoch 329/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4213.6426 - mean_absolute_error: 54.9377 - val_loss: 14171.4062 - val_mean_absolute_error: 117.5068
# Epoch 330/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4254.0239 - mean_absolute_error: 55.0246 - val_loss: 12884.5703 - val_mean_absolute_error: 111.9519
# Epoch 331/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4044.5098 - mean_absolute_error: 53.5578 - val_loss: 12122.2725 - val_mean_absolute_error: 108.5525
# Epoch 332/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4080.6455 - mean_absolute_error: 53.9215 - val_loss: 14195.4297 - val_mean_absolute_error: 117.5892
# Epoch 333/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4245.8892 - mean_absolute_error: 55.1704 - val_loss: 9371.7080 - val_mean_absolute_error: 95.0370
# Epoch 334/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4467.0835 - mean_absolute_error: 56.3974 - val_loss: 13267.8789 - val_mean_absolute_error: 113.6189
# Epoch 335/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4354.5630 - mean_absolute_error: 55.8536 - val_loss: 10417.9355 - val_mean_absolute_error: 100.4523
# Epoch 336/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4300.4092 - mean_absolute_error: 55.5864 - val_loss: 11170.6631 - val_mean_absolute_error: 104.0876
# Epoch 337/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4212.3770 - mean_absolute_error: 55.1254 - val_loss: 12234.6328 - val_mean_absolute_error: 109.0547
# Epoch 338/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4240.3618 - mean_absolute_error: 54.8438 - val_loss: 10956.6650 - val_mean_absolute_error: 103.0935
# Epoch 339/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4150.1406 - mean_absolute_error: 54.5498 - val_loss: 9025.0469 - val_mean_absolute_error: 93.1957
# Epoch 340/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4381.1333 - mean_absolute_error: 55.6917 - val_loss: 12393.4541 - val_mean_absolute_error: 109.7765
# Epoch 341/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4442.4976 - mean_absolute_error: 56.0187 - val_loss: 11527.6924 - val_mean_absolute_error: 105.8053
# Epoch 342/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4126.9653 - mean_absolute_error: 54.1340 - val_loss: 13119.2607 - val_mean_absolute_error: 112.9762
# Epoch 343/1000
# 10/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4018.8252 - mean_absolute_error: 52.5893
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 41
#      38 checkpoint = ModelCheckpoint(f'best_model_SimpleRNN_{num_layers}_{units}_{activation}.keras', monitor='val_mean_absolute_error', mode='min', save_best_only=True)
#      40 # Fitting the RNN to the Training set with the ModelCheckpoint callback
# ---> 41 history = regressor.fit(X_train, y_train, epochs=1000, batch_size=64, validation_data=(X_valid, y_valid), verbose=1, callbacks=[checkpoint])
#      43 history_df = pd.DataFrame({
#      44     'epoch': range(1, len(history.history['loss']) + 1),
#      45     'loss': history.history['loss'],
#    (...)
#      48     'val_mean_absolute_error': history.history['val_mean_absolute_error']
#      49 })
#      50 history_df.to_csv(f'training_history_{num_layers}_{units}_{activation}.csv', index=False)
#
# File ~/pytorchRL/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/pytorchRL/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py:329, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     327 for step, iterator in epoch_iterator.enumerate_epoch():
#     328     callbacks.on_train_batch_begin(step)
# --> 329     logs = self.train_function(iterator)
#     330     callbacks.on_train_batch_end(
#     331         step, self._pythonify_logs(logs)
#     332     )
#     333     if self.stop_training:
#
# File ~/pytorchRL/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/pytorchRL/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/pytorchRL/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File ~/pytorchRL/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File ~/pytorchRL/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/pytorchRL/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File ~/pytorchRL/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File ~/pytorchRL/lib/python3.10/site-packages/tensorflow/python/eager/context.py:1500, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1498 cancellation_context = cancellation.context()
#    1499 if cancellation_context is None:
# -> 1500   outputs = execute.execute(
#    1501       name.decode("utf-8"),
#    1502       num_outputs=num_outputs,
#    1503       inputs=tensor_inputs,
#    1504       attrs=attrs,
#    1505       ctx=self,
#    1506   )
#    1507 else:
#    1508   outputs = execute.execute_with_cancellation(
#    1509       name.decode("utf-8"),
#    1510       num_outputs=num_outputs,
#    (...)
#    1514       cancellation_manager=cancellation_context,
#    1515   )
#
# File ~/pytorchRL/lib/python3.10/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

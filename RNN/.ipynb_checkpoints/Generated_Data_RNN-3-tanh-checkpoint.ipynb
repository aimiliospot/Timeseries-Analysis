# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
# Out:
# 2024-04-24 19:26:24.245029: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-04-24 19:26:24.250686: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-04-24 19:26:24.321354: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-24 19:26:26.570766: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
def plot_series(time, series, format="-", start=0, end=None):
    """
    Visualizes time series data

    Args:
      time (array of int) - contains the time steps
      series (array of int) - contains the measurements for each time step
      format - line style when plotting the graph
      label - tag for the line
      start - first time step to plot
      end - last time step to plot
    """

    # Setup dimensions of the graph figure
    plt.figure(figsize=(10, 6))

    if type(series) is tuple:

      for series_num in series:
        # Plot the time series data
        plt.plot(time[start:end], series_num[start:end], format)

    else:
      # Plot the time series data
      plt.plot(time[start:end], series[start:end], format)

    # Label the x-axis
    plt.xlabel("Time")

    # Label the y-axis
    plt.ylabel("Value")

    # Overlay a grid on the graph
    plt.grid(True)

    # Draw the graph on screen
    plt.show()

def trend(time, slope=0):
    """
    Generates synthetic data that follows a straight line given a slope value.

    Args:
      time (array of int) - contains the time steps
      slope (float) - determines the direction and steepness of the line

    Returns:
      series (array of float) - measurements that follow a straight line
    """

    # Compute the linear series given the slope
    series = slope * time

    return series

def seasonal_pattern(season_time):
    """
    Just an arbitrary pattern, you can change it if you wish

    Args:
      season_time (array of float) - contains the measurements per time step

    Returns:
      data_pattern (array of float) -  contains revised measurement values according
                                  to the defined pattern
    """

    # Generate the values using an arbitrary pattern
    data_pattern = np.where(season_time < 0.4,
                    np.cos(season_time * 2 * np.pi),
                    1 / np.exp(3 * season_time))

    return data_pattern

def seasonality(time, period, amplitude=1, phase=0):
    """
    Repeats the same pattern at each period

    Args:
      time (array of int) - contains the time steps
      period (int) - number of time steps before the pattern repeats
      amplitude (int) - peak measured value in a period
      phase (int) - number of time steps to shift the measured values

    Returns:
      data_pattern (array of float) - seasonal data scaled by the defined amplitude
    """

    # Define the measured values per period
    season_time = ((time + phase) % period) / period

    # Generates the seasonal data scaled by the defined amplitude
    data_pattern = amplitude * seasonal_pattern(season_time)

    return data_pattern

def noise(time, noise_level=1, seed=None):
    """Generates a normally distributed noisy signal

    Args:
      time (array of int) - contains the time steps
      noise_level (float) - scaling factor for the generated signal
      seed (int) - number generator seed for repeatability

    Returns:
      noise (array of float) - the noisy signal
    """

    # Initialize the random number generator
    rnd = np.random.RandomState(seed)

    # Generate a random number for each time step and scale by the noise level
    noise = rnd.randn(len(time)) * noise_level

    return noise


time = np.arange(7 * 365 + 1, dtype="float32")
baseline = 10
amplitude = 50
slope = 0.1
noise_level = 5

# Create the series
series = baseline + trend(time, slope) + seasonality(time, period=365, amplitude=amplitude)

# Update with noise
series += noise(time, noise_level, seed=42)

# Plot the results
plot_series(time, series)

# %%
split_time = 365*6-100

# Get the train set
time_train = time[:split_time]
x_train = series[:split_time]

# Get the validation set
time_valid = time[split_time:]
x_valid = series[split_time:]

plot_series(time_train, x_train)
plot_series(time_valid, x_valid)

# %%
x_train_reshaped = x_train.reshape(-1, 1)
x_valid_reshaped = x_valid.reshape(-1, 1)
plot_series(time_train, x_train_reshaped)
plot_series(time_valid, x_valid_reshaped)

# %%
window_size = 30

x_train_window =[]
y_train_window =[]
x_valid_window =[]
y_valid_window =[]

for i in range (window_size, split_time):
    x_train_window.append(x_train_reshaped[i-window_size:i, 0])
    y_train_window.append(x_train_reshaped[i, 0])



for i in range (window_size,time_valid.shape[0] ):
  x_valid_window.append(x_valid_reshaped[i-window_size:i,0])
  y_valid_window.append(x_valid_reshaped[i,0])

X_train, y_train, X_valid, y_valid = np.array(x_train_window), np.array(y_train_window), np.array(x_valid_window), np.array(y_valid_window)

# %%
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, Dropout
from keras.optimizers import Adam
import matplotlib.pyplot as plt
from keras.metrics import MeanAbsoluteError
from keras.callbacks import ModelCheckpoint

# Initialising the RNN
regressor = Sequential()

# Adding the first SimpleRNN layer and some Dropout regularisation
regressor.add(SimpleRNN(units=50, input_shape=(X_train.shape[1], 1), activation='tanh', return_sequences=True))
regressor.add(Dropout(0.2))

regressor.add(SimpleRNN(units=50, input_shape=(X_train.shape[1], 1), activation='tanh', return_sequences=True))
regressor.add(Dropout(0.2))

regressor.add(SimpleRNN(units=50, activation='tanh'))
regressor.add(Dropout(0.2))

# Adding the output layer
regressor.add(Dense(units=1))



# Compile the model with Adam optimizer and specific learning rate
optimizer = Adam()
regressor.compile(optimizer=optimizer, loss='mean_squared_error', metrics=[MeanAbsoluteError()])

# Define a ModelCheckpoint callback to save the best model
checkpoint = ModelCheckpoint('best_model_SimpleRNN_3_tanh.keras', monitor='val_mean_absolute_error', mode='min', save_best_only=True)

# Fitting the RNN to the Training set with the ModelCheckpoint callback
history = regressor.fit(X_train, y_train, epochs=1000, batch_size=64, validation_data=(X_valid, y_valid), verbose=1, callbacks=[checkpoint])

# Plotting the training and validation loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

plt.plot(history.history['mean_absolute_error'], label='Training MAE')
plt.plot(history.history['val_mean_absolute_error'], label='Validation MAE')
plt.xlabel('Epoch')
plt.ylabel('MAE')
plt.title('Training and Validation MAE')
plt.legend()
plt.show()
# Out:
# Epoch 1/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 8469.5684 - mean_absolute_error: 71.9073 - val_loss: 126.5066 - val_mean_absolute_error: 9.4331
# Epoch 2/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 788.6377 - mean_absolute_error: 20.8708 - val_loss: 114.8258 - val_mean_absolute_error: 7.9350
# Epoch 3/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 579.1319 - mean_absolute_error: 17.4640 - val_loss: 307.6483 - val_mean_absolute_error: 15.7121
# Epoch 4/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 513.8692 - mean_absolute_error: 16.4514 - val_loss: 347.6558 - val_mean_absolute_error: 16.9568
# Epoch 5/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 530.9313 - mean_absolute_error: 17.0287 - val_loss: 169.4603 - val_mean_absolute_error: 10.5824
# Epoch 6/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 488.1766 - mean_absolute_error: 16.0746 - val_loss: 294.1962 - val_mean_absolute_error: 15.3114
# Epoch 7/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 451.9102 - mean_absolute_error: 15.5261 - val_loss: 1144.3568 - val_mean_absolute_error: 32.8924
# Epoch 8/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 476.9273 - mean_absolute_error: 16.0044 - val_loss: 229.0545 - val_mean_absolute_error: 13.0412
# Epoch 9/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 444.1390 - mean_absolute_error: 15.6604 - val_loss: 548.1467 - val_mean_absolute_error: 22.0933
# Epoch 10/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 426.8536 - mean_absolute_error: 15.0322 - val_loss: 288.5796 - val_mean_absolute_error: 15.1836
# Epoch 11/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 458.9766 - mean_absolute_error: 15.4390 - val_loss: 1059.8987 - val_mean_absolute_error: 31.6016
# Epoch 12/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 425.0237 - mean_absolute_error: 15.1998 - val_loss: 233.0573 - val_mean_absolute_error: 13.2608
# Epoch 13/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 428.9033 - mean_absolute_error: 15.3407 - val_loss: 748.1764 - val_mean_absolute_error: 26.2165
# Epoch 14/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 418.3869 - mean_absolute_error: 14.8907 - val_loss: 582.0078 - val_mean_absolute_error: 22.8408
# Epoch 15/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 405.1394 - mean_absolute_error: 15.0048 - val_loss: 138.8097 - val_mean_absolute_error: 9.2443
# Epoch 16/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 416.9370 - mean_absolute_error: 14.9937 - val_loss: 634.4619 - val_mean_absolute_error: 24.0367
# Epoch 17/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 396.7816 - mean_absolute_error: 14.4989 - val_loss: 494.2411 - val_mean_absolute_error: 20.9215
# Epoch 18/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 385.8205 - mean_absolute_error: 14.4503 - val_loss: 118.3914 - val_mean_absolute_error: 8.2440
# Epoch 19/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 367.6488 - mean_absolute_error: 14.0871 - val_loss: 391.6048 - val_mean_absolute_error: 18.3051
# Epoch 20/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 357.3621 - mean_absolute_error: 13.8596 - val_loss: 406.1857 - val_mean_absolute_error: 18.6864
# Epoch 21/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 337.4169 - mean_absolute_error: 13.8228 - val_loss: 660.3297 - val_mean_absolute_error: 24.5434
# Epoch 22/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 382.8640 - mean_absolute_error: 14.1172 - val_loss: 288.1173 - val_mean_absolute_error: 15.1999
# Epoch 23/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 380.3675 - mean_absolute_error: 14.3702 - val_loss: 226.1604 - val_mean_absolute_error: 13.0491
# Epoch 24/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 369.5426 - mean_absolute_error: 14.0700 - val_loss: 415.8508 - val_mean_absolute_error: 18.9449
# Epoch 25/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 335.3952 - mean_absolute_error: 13.6694 - val_loss: 569.2800 - val_mean_absolute_error: 22.6046
# Epoch 26/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 381.3159 - mean_absolute_error: 14.1868 - val_loss: 139.3566 - val_mean_absolute_error: 9.1739
# Epoch 27/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 328.1385 - mean_absolute_error: 13.2035 - val_loss: 1139.7764 - val_mean_absolute_error: 32.8579
# Epoch 28/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 340.0700 - mean_absolute_error: 13.6574 - val_loss: 75.5420 - val_mean_absolute_error: 6.1410
# Epoch 29/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 380.3389 - mean_absolute_error: 14.4140 - val_loss: 583.3389 - val_mean_absolute_error: 22.9171
# Epoch 30/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 315.3200 - mean_absolute_error: 13.1306 - val_loss: 500.5857 - val_mean_absolute_error: 21.0116
# Epoch 31/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 338.1418 - mean_absolute_error: 13.3592 - val_loss: 89.1273 - val_mean_absolute_error: 6.6830
# Epoch 32/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 349.6169 - mean_absolute_error: 13.5653 - val_loss: 272.6998 - val_mean_absolute_error: 14.6700
# Epoch 33/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 338.7371 - mean_absolute_error: 13.4672 - val_loss: 993.5199 - val_mean_absolute_error: 30.5850
# Epoch 34/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 325.4890 - mean_absolute_error: 13.0701 - val_loss: 361.0499 - val_mean_absolute_error: 17.4518
# Epoch 35/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 369.8501 - mean_absolute_error: 14.1537 - val_loss: 315.6638 - val_mean_absolute_error: 16.1292
# Epoch 36/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 295.3674 - mean_absolute_error: 12.9050 - val_loss: 913.5387 - val_mean_absolute_error: 29.2442
# Epoch 37/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 349.7012 - mean_absolute_error: 13.5139 - val_loss: 1799.6218 - val_mean_absolute_error: 41.6887
# Epoch 38/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 377.9849 - mean_absolute_error: 14.4549 - val_loss: 897.9529 - val_mean_absolute_error: 28.9797
# Epoch 39/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 330.5981 - mean_absolute_error: 13.4753 - val_loss: 318.8463 - val_mean_absolute_error: 16.1809
# Epoch 40/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 308.5886 - mean_absolute_error: 12.9574 - val_loss: 62.5971 - val_mean_absolute_error: 5.6471
# Epoch 41/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 435.1319 - mean_absolute_error: 15.0569 - val_loss: 733.1296 - val_mean_absolute_error: 26.0075
# Epoch 42/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 353.1640 - mean_absolute_error: 13.9068 - val_loss: 743.6045 - val_mean_absolute_error: 26.1984
# Epoch 43/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 338.4262 - mean_absolute_error: 13.7043 - val_loss: 330.2580 - val_mean_absolute_error: 16.5021
# Epoch 44/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 285.7873 - mean_absolute_error: 12.4727 - val_loss: 736.7459 - val_mean_absolute_error: 26.0806
# Epoch 45/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 347.8750 - mean_absolute_error: 13.5225 - val_loss: 522.7065 - val_mean_absolute_error: 21.5860
# Epoch 46/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 314.5916 - mean_absolute_error: 13.0138 - val_loss: 1134.7467 - val_mean_absolute_error: 32.8043
# Epoch 47/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 336.4890 - mean_absolute_error: 13.2257 - val_loss: 564.4033 - val_mean_absolute_error: 22.5082
# Epoch 48/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 330.0443 - mean_absolute_error: 13.3098 - val_loss: 160.0201 - val_mean_absolute_error: 10.2202
# Epoch 49/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 312.9036 - mean_absolute_error: 13.2449 - val_loss: 566.6461 - val_mean_absolute_error: 22.5925
# Epoch 50/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 268.3473 - mean_absolute_error: 12.3092 - val_loss: 208.6054 - val_mean_absolute_error: 12.2847
# Epoch 51/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 313.6795 - mean_absolute_error: 12.9324 - val_loss: 1118.0240 - val_mean_absolute_error: 32.5503
# Epoch 52/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 285.3922 - mean_absolute_error: 12.5785 - val_loss: 155.5455 - val_mean_absolute_error: 10.0285
# Epoch 53/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 291.4453 - mean_absolute_error: 12.7120 - val_loss: 885.9326 - val_mean_absolute_error: 28.7902
# Epoch 54/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 323.1791 - mean_absolute_error: 13.4691 - val_loss: 816.7816 - val_mean_absolute_error: 27.5604
# Epoch 55/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 295.9745 - mean_absolute_error: 12.6563 - val_loss: 399.5852 - val_mean_absolute_error: 18.5522
# Epoch 56/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 281.0557 - mean_absolute_error: 12.3958 - val_loss: 809.7307 - val_mean_absolute_error: 27.4128
# Epoch 57/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 265.2752 - mean_absolute_error: 12.2304 - val_loss: 183.2095 - val_mean_absolute_error: 11.1830
# Epoch 58/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 292.3282 - mean_absolute_error: 12.6078 - val_loss: 439.9816 - val_mean_absolute_error: 19.6118
# Epoch 59/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 311.6759 - mean_absolute_error: 13.0498 - val_loss: 683.7999 - val_mean_absolute_error: 25.0546
# Epoch 60/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 283.4823 - mean_absolute_error: 12.5378 - val_loss: 1530.9443 - val_mean_absolute_error: 38.3365
# Epoch 61/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 309.2945 - mean_absolute_error: 12.8130 - val_loss: 830.9111 - val_mean_absolute_error: 27.8293
# Epoch 62/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 288.9313 - mean_absolute_error: 12.6092 - val_loss: 1052.8579 - val_mean_absolute_error: 31.5351
# Epoch 63/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 272.5841 - mean_absolute_error: 12.1206 - val_loss: 1062.3872 - val_mean_absolute_error: 31.6813
# Epoch 64/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 284.0635 - mean_absolute_error: 12.3706 - val_loss: 729.0793 - val_mean_absolute_error: 25.8759
# Epoch 65/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 294.9414 - mean_absolute_error: 12.4527 - val_loss: 434.3516 - val_mean_absolute_error: 19.3451
# Epoch 66/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 275.0346 - mean_absolute_error: 12.2926 - val_loss: 122.8620 - val_mean_absolute_error: 8.3317
# Epoch 67/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 300.8248 - mean_absolute_error: 12.8290 - val_loss: 1278.7592 - val_mean_absolute_error: 34.9173
# Epoch 68/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 313.9540 - mean_absolute_error: 13.0613 - val_loss: 362.1775 - val_mean_absolute_error: 17.5081
# Epoch 69/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 315.5815 - mean_absolute_error: 13.0987 - val_loss: 1124.5663 - val_mean_absolute_error: 32.6541
# Epoch 70/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 298.0455 - mean_absolute_error: 12.9804 - val_loss: 96.4963 - val_mean_absolute_error: 7.1563
# Epoch 71/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 297.9521 - mean_absolute_error: 12.5360 - val_loss: 2038.0024 - val_mean_absolute_error: 44.4492
# Epoch 72/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 351.7615 - mean_absolute_error: 13.7606 - val_loss: 1365.6653 - val_mean_absolute_error: 36.1466
# Epoch 73/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 259.8990 - mean_absolute_error: 11.9285 - val_loss: 361.8911 - val_mean_absolute_error: 17.4736
# Epoch 74/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 293.1394 - mean_absolute_error: 12.6676 - val_loss: 838.8392 - val_mean_absolute_error: 27.9663
# Epoch 75/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 271.4703 - mean_absolute_error: 12.0358 - val_loss: 495.2442 - val_mean_absolute_error: 20.9624
# Epoch 76/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 284.2472 - mean_absolute_error: 12.6040 - val_loss: 628.7819 - val_mean_absolute_error: 23.9364
# Epoch 77/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 272.4720 - mean_absolute_error: 12.1822 - val_loss: 950.2943 - val_mean_absolute_error: 29.8811
# Epoch 78/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 257.2563 - mean_absolute_error: 11.9211 - val_loss: 402.4388 - val_mean_absolute_error: 18.5720
# Epoch 79/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 271.0089 - mean_absolute_error: 12.1981 - val_loss: 124.9302 - val_mean_absolute_error: 8.5634
# Epoch 80/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 282.3656 - mean_absolute_error: 12.4411 - val_loss: 841.4919 - val_mean_absolute_error: 28.0282
# Epoch 81/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 278.3714 - mean_absolute_error: 12.3835 - val_loss: 105.5667 - val_mean_absolute_error: 7.7521
# Epoch 82/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 294.4811 - mean_absolute_error: 12.4986 - val_loss: 258.0320 - val_mean_absolute_error: 14.2764
# Epoch 83/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 280.5921 - mean_absolute_error: 12.2448 - val_loss: 122.9379 - val_mean_absolute_error: 8.5051
# Epoch 84/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 268.9495 - mean_absolute_error: 12.0944 - val_loss: 770.8738 - val_mean_absolute_error: 26.7361
# Epoch 85/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 265.5727 - mean_absolute_error: 12.1370 - val_loss: 218.3038 - val_mean_absolute_error: 12.6593
# Epoch 86/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 293.2001 - mean_absolute_error: 12.6392 - val_loss: 384.2432 - val_mean_absolute_error: 18.1280
# Epoch 87/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 251.3763 - mean_absolute_error: 11.5884 - val_loss: 460.3409 - val_mean_absolute_error: 20.1019
# Epoch 88/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 258.1677 - mean_absolute_error: 11.7626 - val_loss: 1257.3711 - val_mean_absolute_error: 34.6305
# Epoch 89/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 295.1408 - mean_absolute_error: 12.4765 - val_loss: 464.9385 - val_mean_absolute_error: 20.2306
# Epoch 90/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 284.4301 - mean_absolute_error: 12.2730 - val_loss: 967.2562 - val_mean_absolute_error: 30.1742
# Epoch 91/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 263.4449 - mean_absolute_error: 12.0206 - val_loss: 327.4087 - val_mean_absolute_error: 16.4108
# Epoch 92/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 269.6967 - mean_absolute_error: 12.1836 - val_loss: 688.4235 - val_mean_absolute_error: 25.1557
# Epoch 93/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 262.7813 - mean_absolute_error: 12.0445 - val_loss: 636.2427 - val_mean_absolute_error: 24.0666
# Epoch 94/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 258.5035 - mean_absolute_error: 11.7112 - val_loss: 304.7654 - val_mean_absolute_error: 15.8059
# Epoch 95/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 273.3109 - mean_absolute_error: 12.1589 - val_loss: 285.3491 - val_mean_absolute_error: 15.0036
# Epoch 96/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 269.3069 - mean_absolute_error: 11.9292 - val_loss: 1047.3947 - val_mean_absolute_error: 31.4755
# Epoch 97/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 262.5902 - mean_absolute_error: 11.9807 - val_loss: 1081.0355 - val_mean_absolute_error: 31.9844
# Epoch 98/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 274.5318 - mean_absolute_error: 12.0806 - val_loss: 571.0676 - val_mean_absolute_error: 22.5818
# Epoch 99/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 254.3018 - mean_absolute_error: 11.5365 - val_loss: 967.2792 - val_mean_absolute_error: 30.1545
# Epoch 100/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 270.6031 - mean_absolute_error: 11.8753 - val_loss: 754.4673 - val_mean_absolute_error: 26.4126
# Epoch 101/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 303.4182 - mean_absolute_error: 12.7679 - val_loss: 624.2603 - val_mean_absolute_error: 23.7707
# Epoch 102/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 229.4292 - mean_absolute_error: 11.0709 - val_loss: 714.8155 - val_mean_absolute_error: 25.6595
# Epoch 103/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 286.6291 - mean_absolute_error: 12.3134 - val_loss: 559.7247 - val_mean_absolute_error: 22.4453
# Epoch 104/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 296.8530 - mean_absolute_error: 12.9257 - val_loss: 818.6340 - val_mean_absolute_error: 27.6245
# Epoch 105/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 282.9835 - mean_absolute_error: 12.1678 - val_loss: 949.0070 - val_mean_absolute_error: 29.8803
# Epoch 106/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 248.7353 - mean_absolute_error: 11.6287 - val_loss: 1394.2352 - val_mean_absolute_error: 36.5444
# Epoch 107/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 279.2360 - mean_absolute_error: 12.2008 - val_loss: 1082.7389 - val_mean_absolute_error: 32.0103
# Epoch 108/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 278.8069 - mean_absolute_error: 12.1134 - val_loss: 949.5450 - val_mean_absolute_error: 29.8734
# Epoch 109/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 280.1330 - mean_absolute_error: 12.2790 - val_loss: 544.3699 - val_mean_absolute_error: 22.1182
# Epoch 110/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 263.7394 - mean_absolute_error: 11.8815 - val_loss: 741.8665 - val_mean_absolute_error: 26.1971
# Epoch 111/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 262.5097 - mean_absolute_error: 11.8181 - val_loss: 458.5103 - val_mean_absolute_error: 20.0446
# Epoch 112/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 253.7083 - mean_absolute_error: 11.7622 - val_loss: 1879.3655 - val_mean_absolute_error: 42.6327
# Epoch 113/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 300.1483 - mean_absolute_error: 12.7112 - val_loss: 673.0140 - val_mean_absolute_error: 24.8377
# Epoch 114/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 245.9271 - mean_absolute_error: 11.4413 - val_loss: 494.1603 - val_mean_absolute_error: 20.9133
# Epoch 115/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 260.0352 - mean_absolute_error: 11.8392 - val_loss: 317.4657 - val_mean_absolute_error: 16.1455
# Epoch 116/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 242.6980 - mean_absolute_error: 11.5341 - val_loss: 1351.3949 - val_mean_absolute_error: 35.9721
# Epoch 117/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 290.1286 - mean_absolute_error: 12.5825 - val_loss: 569.3845 - val_mean_absolute_error: 22.6510
# Epoch 118/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 265.1535 - mean_absolute_error: 11.7485 - val_loss: 1233.4203 - val_mean_absolute_error: 34.2547
# Epoch 119/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 260.9921 - mean_absolute_error: 11.8135 - val_loss: 1218.7468 - val_mean_absolute_error: 34.0717
# Epoch 120/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 281.3363 - mean_absolute_error: 12.4316 - val_loss: 768.3365 - val_mean_absolute_error: 26.6768
# Epoch 121/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 279.9783 - mean_absolute_error: 12.1070 - val_loss: 1014.0966 - val_mean_absolute_error: 30.9330
# Epoch 122/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 256.4432 - mean_absolute_error: 11.7634 - val_loss: 1053.7424 - val_mean_absolute_error: 31.5845
# Epoch 123/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 242.0303 - mean_absolute_error: 11.3826 - val_loss: 1047.4764 - val_mean_absolute_error: 31.4812
# Epoch 124/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 258.2085 - mean_absolute_error: 11.8815 - val_loss: 113.3011 - val_mean_absolute_error: 8.2639
# Epoch 125/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 331.1856 - mean_absolute_error: 13.2573 - val_loss: 1121.4617 - val_mean_absolute_error: 32.6371
# Epoch 126/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 252.1024 - mean_absolute_error: 11.6899 - val_loss: 1098.1176 - val_mean_absolute_error: 32.2587
# Epoch 127/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 261.0306 - mean_absolute_error: 12.0400 - val_loss: 1145.5948 - val_mean_absolute_error: 32.9740
# Epoch 128/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 236.8342 - mean_absolute_error: 11.4960 - val_loss: 444.7176 - val_mean_absolute_error: 19.7710
# Epoch 129/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 253.1980 - mean_absolute_error: 11.8780 - val_loss: 1828.2925 - val_mean_absolute_error: 42.0494
# Epoch 130/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 290.9806 - mean_absolute_error: 12.5899 - val_loss: 708.9445 - val_mean_absolute_error: 25.5482
# Epoch 131/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 259.4366 - mean_absolute_error: 11.8737 - val_loss: 545.3323 - val_mean_absolute_error: 22.1683
# Epoch 132/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 231.0588 - mean_absolute_error: 11.1467 - val_loss: 635.5732 - val_mean_absolute_error: 24.0912
# Epoch 133/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 247.5794 - mean_absolute_error: 11.5484 - val_loss: 974.2553 - val_mean_absolute_error: 30.2973
# Epoch 134/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 247.5583 - mean_absolute_error: 11.6033 - val_loss: 254.1083 - val_mean_absolute_error: 13.9998
# Epoch 135/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 265.9843 - mean_absolute_error: 11.9093 - val_loss: 1551.4120 - val_mean_absolute_error: 38.6484
# Epoch 136/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 275.6362 - mean_absolute_error: 12.2211 - val_loss: 891.9415 - val_mean_absolute_error: 28.9300
# Epoch 137/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 259.6767 - mean_absolute_error: 11.7531 - val_loss: 689.5408 - val_mean_absolute_error: 25.2080
# Epoch 138/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 251.3690 - mean_absolute_error: 11.6446 - val_loss: 378.9270 - val_mean_absolute_error: 18.0501
# Epoch 139/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 268.0227 - mean_absolute_error: 12.0656 - val_loss: 755.1439 - val_mean_absolute_error: 26.4647
# Epoch 140/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 294.4429 - mean_absolute_error: 12.4402 - val_loss: 271.6288 - val_mean_absolute_error: 14.7267
# Epoch 141/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 251.6645 - mean_absolute_error: 11.6751 - val_loss: 991.4023 - val_mean_absolute_error: 30.5710
# Epoch 142/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 226.0511 - mean_absolute_error: 11.2836 - val_loss: 1335.4276 - val_mean_absolute_error: 35.7374
# Epoch 143/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 249.3641 - mean_absolute_error: 11.7762 - val_loss: 852.1172 - val_mean_absolute_error: 28.2000
# Epoch 144/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 247.2423 - mean_absolute_error: 11.4380 - val_loss: 820.0128 - val_mean_absolute_error: 27.6478
# Epoch 145/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 236.9079 - mean_absolute_error: 11.3993 - val_loss: 1161.1199 - val_mean_absolute_error: 33.2312
# Epoch 146/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 242.0051 - mean_absolute_error: 11.4983 - val_loss: 1295.9087 - val_mean_absolute_error: 35.1767
# Epoch 147/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 251.6862 - mean_absolute_error: 11.8265 - val_loss: 1224.7482 - val_mean_absolute_error: 34.1531
# Epoch 148/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 246.8126 - mean_absolute_error: 11.5816 - val_loss: 914.8795 - val_mean_absolute_error: 29.3022
# Epoch 149/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 248.6017 - mean_absolute_error: 11.7798 - val_loss: 647.9473 - val_mean_absolute_error: 24.3602
# Epoch 150/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 280.9580 - mean_absolute_error: 12.5289 - val_loss: 1247.4221 - val_mean_absolute_error: 34.4802
# Epoch 151/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 237.2691 - mean_absolute_error: 11.5763 - val_loss: 935.6966 - val_mean_absolute_error: 29.6476
# Epoch 152/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 258.4257 - mean_absolute_error: 11.9063 - val_loss: 1540.5427 - val_mean_absolute_error: 38.4869
# Epoch 153/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 264.2154 - mean_absolute_error: 11.8762 - val_loss: 1008.6018 - val_mean_absolute_error: 30.8413
# Epoch 154/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 262.6081 - mean_absolute_error: 11.8876 - val_loss: 542.9109 - val_mean_absolute_error: 22.0862
# Epoch 155/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 259.4751 - mean_absolute_error: 11.9221 - val_loss: 1256.2534 - val_mean_absolute_error: 34.6051
# Epoch 156/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 231.8236 - mean_absolute_error: 11.2385 - val_loss: 800.7184 - val_mean_absolute_error: 27.2968
# Epoch 157/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 231.4889 - mean_absolute_error: 11.3395 - val_loss: 839.5793 - val_mean_absolute_error: 27.9937
# Epoch 158/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 234.3388 - mean_absolute_error: 11.1457 - val_loss: 1071.5815 - val_mean_absolute_error: 31.8422
# Epoch 159/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 238.5327 - mean_absolute_error: 11.5317 - val_loss: 1610.8965 - val_mean_absolute_error: 39.3811
# Epoch 160/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 260.9755 - mean_absolute_error: 11.7202 - val_loss: 1016.4897 - val_mean_absolute_error: 30.9903
# Epoch 161/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 235.9637 - mean_absolute_error: 11.2385 - val_loss: 1739.4102 - val_mean_absolute_error: 40.9842
# Epoch 162/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 277.9918 - mean_absolute_error: 11.8363 - val_loss: 1439.0350 - val_mean_absolute_error: 37.1477
# Epoch 163/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 246.1699 - mean_absolute_error: 11.4422 - val_loss: 634.5320 - val_mean_absolute_error: 24.0606
# Epoch 164/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 231.2633 - mean_absolute_error: 11.3333 - val_loss: 619.6334 - val_mean_absolute_error: 23.7387
# Epoch 165/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 234.1664 - mean_absolute_error: 11.2247 - val_loss: 780.6698 - val_mean_absolute_error: 26.9184
# Epoch 166/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 233.9373 - mean_absolute_error: 11.2959 - val_loss: 680.0599 - val_mean_absolute_error: 24.9858
# Epoch 167/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 243.8342 - mean_absolute_error: 11.3451 - val_loss: 1419.7324 - val_mean_absolute_error: 36.8921
# Epoch 168/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 252.6044 - mean_absolute_error: 11.4321 - val_loss: 751.8367 - val_mean_absolute_error: 26.3920
# Epoch 169/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 258.4653 - mean_absolute_error: 11.7434 - val_loss: 1482.3503 - val_mean_absolute_error: 37.7271
# Epoch 170/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 249.3340 - mean_absolute_error: 11.5353 - val_loss: 639.2526 - val_mean_absolute_error: 24.1478
# Epoch 171/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 240.6394 - mean_absolute_error: 11.6292 - val_loss: 982.8084 - val_mean_absolute_error: 30.4188
# Epoch 172/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 238.1986 - mean_absolute_error: 11.4994 - val_loss: 1523.8163 - val_mean_absolute_error: 38.2644
# Epoch 173/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 242.0536 - mean_absolute_error: 11.6182 - val_loss: 1163.1438 - val_mean_absolute_error: 33.2479
# Epoch 174/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 227.1903 - mean_absolute_error: 11.2630 - val_loss: 1396.8577 - val_mean_absolute_error: 36.5876
# Epoch 175/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 244.0957 - mean_absolute_error: 11.6832 - val_loss: 1343.2844 - val_mean_absolute_error: 35.8570
# Epoch 176/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 242.0054 - mean_absolute_error: 11.2419 - val_loss: 1687.2721 - val_mean_absolute_error: 40.3438
# Epoch 177/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 238.4839 - mean_absolute_error: 11.1671 - val_loss: 805.2844 - val_mean_absolute_error: 27.3614
# Epoch 178/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 216.7056 - mean_absolute_error: 10.8375 - val_loss: 905.4892 - val_mean_absolute_error: 29.1383
# Epoch 179/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 242.0825 - mean_absolute_error: 11.5051 - val_loss: 713.1649 - val_mean_absolute_error: 25.6331
# Epoch 180/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 231.5464 - mean_absolute_error: 11.2387 - val_loss: 2270.8293 - val_mean_absolute_error: 46.9952
# Epoch 181/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 235.4685 - mean_absolute_error: 11.3451 - val_loss: 1075.4994 - val_mean_absolute_error: 31.9084
# Epoch 182/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 233.8758 - mean_absolute_error: 11.3076 - val_loss: 2058.2869 - val_mean_absolute_error: 44.6874
# Epoch 183/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 242.0683 - mean_absolute_error: 11.3926 - val_loss: 1547.0387 - val_mean_absolute_error: 38.5731
# Epoch 184/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 259.3345 - mean_absolute_error: 11.7977 - val_loss: 1642.6470 - val_mean_absolute_error: 39.7820
# Epoch 185/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 237.7469 - mean_absolute_error: 11.6644 - val_loss: 1990.0364 - val_mean_absolute_error: 43.9186
# Epoch 186/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 236.9053 - mean_absolute_error: 11.4820 - val_loss: 1233.3029 - val_mean_absolute_error: 34.2881
# Epoch 187/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 239.1496 - mean_absolute_error: 11.4251 - val_loss: 1519.5459 - val_mean_absolute_error: 38.2247
# Epoch 188/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 230.5197 - mean_absolute_error: 11.1962 - val_loss: 2035.4233 - val_mean_absolute_error: 44.4351
# Epoch 189/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 223.3353 - mean_absolute_error: 11.1000 - val_loss: 856.5892 - val_mean_absolute_error: 28.2893
# Epoch 190/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 234.8751 - mean_absolute_error: 11.4408 - val_loss: 1606.5837 - val_mean_absolute_error: 39.3335
# Epoch 191/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 221.4448 - mean_absolute_error: 10.9220 - val_loss: 1464.7961 - val_mean_absolute_error: 37.5028
# Epoch 192/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 251.7787 - mean_absolute_error: 11.6715 - val_loss: 2458.1052 - val_mean_absolute_error: 48.9413
# Epoch 193/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 257.1651 - mean_absolute_error: 11.9501 - val_loss: 1746.5653 - val_mean_absolute_error: 41.0652
# Epoch 194/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 219.3700 - mean_absolute_error: 10.9395 - val_loss: 1139.1909 - val_mean_absolute_error: 32.8723
# Epoch 195/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 238.1740 - mean_absolute_error: 11.5653 - val_loss: 1298.3140 - val_mean_absolute_error: 35.2126
# Epoch 196/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 232.5839 - mean_absolute_error: 11.2367 - val_loss: 1454.4094 - val_mean_absolute_error: 37.3580
# Epoch 197/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 243.1142 - mean_absolute_error: 11.2408 - val_loss: 1409.9208 - val_mean_absolute_error: 36.7538
# Epoch 198/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 232.3761 - mean_absolute_error: 10.9554 - val_loss: 538.6668 - val_mean_absolute_error: 21.9451
# Epoch 199/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 262.5462 - mean_absolute_error: 12.1684 - val_loss: 1178.2379 - val_mean_absolute_error: 33.4764
# Epoch 200/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 217.8030 - mean_absolute_error: 10.9148 - val_loss: 1324.5864 - val_mean_absolute_error: 35.5866
# Epoch 201/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 210.9280 - mean_absolute_error: 10.7785 - val_loss: 1436.3000 - val_mean_absolute_error: 37.1181
# Epoch 202/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 228.6709 - mean_absolute_error: 11.0140 - val_loss: 1477.4786 - val_mean_absolute_error: 37.6592
# Epoch 203/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 213.4300 - mean_absolute_error: 10.8025 - val_loss: 2557.6519 - val_mean_absolute_error: 49.9410
# Epoch 204/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 261.0182 - mean_absolute_error: 11.6989 - val_loss: 2529.7166 - val_mean_absolute_error: 49.6593
# Epoch 205/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 269.6337 - mean_absolute_error: 12.0227 - val_loss: 1807.0044 - val_mean_absolute_error: 41.7803
# Epoch 206/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 218.2733 - mean_absolute_error: 10.9188 - val_loss: 1632.9142 - val_mean_absolute_error: 39.6559
# Epoch 207/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 242.4009 - mean_absolute_error: 11.5701 - val_loss: 1176.9279 - val_mean_absolute_error: 33.4372
# Epoch 208/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 261.0407 - mean_absolute_error: 12.0154 - val_loss: 1535.6477 - val_mean_absolute_error: 38.4179
# Epoch 209/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 216.3517 - mean_absolute_error: 10.9989 - val_loss: 2545.0613 - val_mean_absolute_error: 49.8110
# Epoch 210/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 232.1777 - mean_absolute_error: 11.3957 - val_loss: 1330.3304 - val_mean_absolute_error: 35.6588
# Epoch 211/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 211.6655 - mean_absolute_error: 10.7502 - val_loss: 2618.8403 - val_mean_absolute_error: 50.5457
# Epoch 212/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 244.3873 - mean_absolute_error: 11.4232 - val_loss: 2354.9058 - val_mean_absolute_error: 47.8697
# Epoch 213/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 253.3930 - mean_absolute_error: 11.6705 - val_loss: 1493.9645 - val_mean_absolute_error: 37.8772
# Epoch 214/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 215.1346 - mean_absolute_error: 10.8072 - val_loss: 1476.5638 - val_mean_absolute_error: 37.6450
# Epoch 215/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 203.2682 - mean_absolute_error: 10.6397 - val_loss: 1748.4303 - val_mean_absolute_error: 41.0879
# Epoch 216/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 224.7345 - mean_absolute_error: 11.1177 - val_loss: 1879.6284 - val_mean_absolute_error: 42.6462
# Epoch 217/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 231.9997 - mean_absolute_error: 11.3858 - val_loss: 2127.1272 - val_mean_absolute_error: 45.4449
# Epoch 218/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 234.0423 - mean_absolute_error: 11.3167 - val_loss: 1588.2372 - val_mean_absolute_error: 39.0957
# Epoch 219/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 212.8805 - mean_absolute_error: 10.7427 - val_loss: 1678.1621 - val_mean_absolute_error: 40.2276
# Epoch 220/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 233.5469 - mean_absolute_error: 11.2617 - val_loss: 1786.2982 - val_mean_absolute_error: 41.5476
# Epoch 221/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 225.6224 - mean_absolute_error: 11.0401 - val_loss: 1693.0863 - val_mean_absolute_error: 40.4056
# Epoch 222/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 208.7929 - mean_absolute_error: 10.6347 - val_loss: 1766.6525 - val_mean_absolute_error: 41.3091
# Epoch 223/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 231.6334 - mean_absolute_error: 11.3754 - val_loss: 1699.9569 - val_mean_absolute_error: 40.4988
# Epoch 224/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 219.4108 - mean_absolute_error: 10.9072 - val_loss: 2292.1174 - val_mean_absolute_error: 47.2182
# Epoch 225/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 229.9169 - mean_absolute_error: 11.3079 - val_loss: 1739.2272 - val_mean_absolute_error: 40.9703
# Epoch 226/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 206.5954 - mean_absolute_error: 10.6661 - val_loss: 2177.7959 - val_mean_absolute_error: 45.9943
# Epoch 227/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 215.3128 - mean_absolute_error: 10.8660 - val_loss: 2547.5098 - val_mean_absolute_error: 49.8378
# Epoch 228/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 252.2686 - mean_absolute_error: 11.8013 - val_loss: 2145.5725 - val_mean_absolute_error: 45.6478
# Epoch 229/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 248.3234 - mean_absolute_error: 11.4322 - val_loss: 1589.2147 - val_mean_absolute_error: 39.1000
# Epoch 230/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 212.3236 - mean_absolute_error: 10.7021 - val_loss: 2331.7766 - val_mean_absolute_error: 47.6212
# Epoch 231/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 238.9017 - mean_absolute_error: 11.3092 - val_loss: 1680.6965 - val_mean_absolute_error: 40.2653
# Epoch 232/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 208.1725 - mean_absolute_error: 11.0284 - val_loss: 1980.9911 - val_mean_absolute_error: 43.8189
# Epoch 233/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 215.0051 - mean_absolute_error: 10.7258 - val_loss: 2090.4026 - val_mean_absolute_error: 45.0427
# Epoch 234/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 210.2643 - mean_absolute_error: 10.7447 - val_loss: 2714.6577 - val_mean_absolute_error: 51.4741
# Epoch 235/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 201.6068 - mean_absolute_error: 10.4444 - val_loss: 2573.8877 - val_mean_absolute_error: 50.0939
# Epoch 236/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 220.8385 - mean_absolute_error: 10.8164 - val_loss: 1984.7749 - val_mean_absolute_error: 43.8531
# Epoch 237/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 256.5437 - mean_absolute_error: 11.5604 - val_loss: 1650.5438 - val_mean_absolute_error: 39.8889
# Epoch 238/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 212.8994 - mean_absolute_error: 10.7518 - val_loss: 2260.9224 - val_mean_absolute_error: 46.8935
# Epoch 239/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 206.5338 - mean_absolute_error: 10.7396 - val_loss: 1902.5048 - val_mean_absolute_error: 42.9183
# Epoch 240/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 227.2118 - mean_absolute_error: 11.0456 - val_loss: 1055.3895 - val_mean_absolute_error: 31.5902
# Epoch 241/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 249.0921 - mean_absolute_error: 11.4896 - val_loss: 1801.0016 - val_mean_absolute_error: 41.7254
# Epoch 242/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 205.8160 - mean_absolute_error: 10.5511 - val_loss: 2998.1313 - val_mean_absolute_error: 54.1536
# Epoch 243/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 193.0265 - mean_absolute_error: 10.3606 - val_loss: 2946.4026 - val_mean_absolute_error: 53.6740
# Epoch 244/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 217.8342 - mean_absolute_error: 10.9570 - val_loss: 2045.9299 - val_mean_absolute_error: 44.5550
# Epoch 245/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 233.6458 - mean_absolute_error: 11.0444 - val_loss: 2344.9163 - val_mean_absolute_error: 47.7775
# Epoch 246/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 217.0046 - mean_absolute_error: 10.8410 - val_loss: 2415.4741 - val_mean_absolute_error: 48.5084
# Epoch 247/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 207.6827 - mean_absolute_error: 10.5206 - val_loss: 1609.8848 - val_mean_absolute_error: 39.3778
# Epoch 248/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 184.6079 - mean_absolute_error: 9.9391 - val_loss: 2785.7319 - val_mean_absolute_error: 52.1543
# Epoch 249/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 207.3858 - mean_absolute_error: 10.5570 - val_loss: 1730.3851 - val_mean_absolute_error: 40.8647
# Epoch 250/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 220.9714 - mean_absolute_error: 10.8824 - val_loss: 1613.2670 - val_mean_absolute_error: 39.4263
# Epoch 251/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 233.1713 - mean_absolute_error: 11.1318 - val_loss: 2319.0054 - val_mean_absolute_error: 47.5075
# Epoch 252/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 210.5560 - mean_absolute_error: 10.6091 - val_loss: 2383.0613 - val_mean_absolute_error: 48.1747
# Epoch 253/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 243.5570 - mean_absolute_error: 11.3351 - val_loss: 2687.4536 - val_mean_absolute_error: 51.2223
# Epoch 254/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 216.4557 - mean_absolute_error: 10.7076 - val_loss: 2287.1313 - val_mean_absolute_error: 47.1760
# Epoch 255/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 208.0457 - mean_absolute_error: 10.6141 - val_loss: 1955.2155 - val_mean_absolute_error: 43.5265
# Epoch 256/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 187.1563 - mean_absolute_error: 10.1288 - val_loss: 2352.7471 - val_mean_absolute_error: 47.8500
# Epoch 257/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 219.6089 - mean_absolute_error: 10.7311 - val_loss: 2259.9116 - val_mean_absolute_error: 46.8724
# Epoch 258/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 206.3066 - mean_absolute_error: 10.4302 - val_loss: 1626.7030 - val_mean_absolute_error: 39.5936
# Epoch 259/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 207.8045 - mean_absolute_error: 10.8529 - val_loss: 2168.9702 - val_mean_absolute_error: 45.9174
# Epoch 260/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 189.6015 - mean_absolute_error: 10.2035 - val_loss: 2478.2380 - val_mean_absolute_error: 49.1481
# Epoch 261/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 217.1795 - mean_absolute_error: 10.9725 - val_loss: 2053.4207 - val_mean_absolute_error: 44.6401
# Epoch 262/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 221.5905 - mean_absolute_error: 10.8494 - val_loss: 2783.0259 - val_mean_absolute_error: 52.1416
# Epoch 263/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 225.5597 - mean_absolute_error: 11.0264 - val_loss: 2035.9929 - val_mean_absolute_error: 44.4501
# Epoch 264/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 220.7807 - mean_absolute_error: 11.0853 - val_loss: 1690.9501 - val_mean_absolute_error: 40.4011
# Epoch 265/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 224.2348 - mean_absolute_error: 10.8426 - val_loss: 2496.5701 - val_mean_absolute_error: 49.3389
# Epoch 266/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 201.6632 - mean_absolute_error: 10.4142 - val_loss: 2557.6553 - val_mean_absolute_error: 49.9476
# Epoch 267/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 200.4104 - mean_absolute_error: 10.4319 - val_loss: 2829.0818 - val_mean_absolute_error: 52.5923
# Epoch 268/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 230.4258 - mean_absolute_error: 10.8383 - val_loss: 3180.0234 - val_mean_absolute_error: 55.8097
# Epoch 269/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 210.5165 - mean_absolute_error: 10.7645 - val_loss: 2461.0410 - val_mean_absolute_error: 48.9886
# Epoch 270/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 208.3670 - mean_absolute_error: 10.6390 - val_loss: 2645.1458 - val_mean_absolute_error: 50.8232
# Epoch 271/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 194.5067 - mean_absolute_error: 10.1058 - val_loss: 2589.1157 - val_mean_absolute_error: 50.2732
# Epoch 272/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 205.4744 - mean_absolute_error: 10.6161 - val_loss: 3177.8882 - val_mean_absolute_error: 55.7777
# Epoch 273/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 224.5878 - mean_absolute_error: 10.9486 - val_loss: 3393.1465 - val_mean_absolute_error: 57.6858
# Epoch 274/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 238.6774 - mean_absolute_error: 11.4493 - val_loss: 2579.1096 - val_mean_absolute_error: 50.1718
# Epoch 275/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 207.9953 - mean_absolute_error: 10.4483 - val_loss: 2827.9221 - val_mean_absolute_error: 52.5798
# Epoch 276/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 196.6912 - mean_absolute_error: 10.5657 - val_loss: 2255.2168 - val_mean_absolute_error: 46.8473
# Epoch 277/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 218.8678 - mean_absolute_error: 10.9332 - val_loss: 1244.9989 - val_mean_absolute_error: 34.4802
# Epoch 278/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 247.5860 - mean_absolute_error: 11.4364 - val_loss: 2004.7666 - val_mean_absolute_error: 44.1050
# Epoch 279/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 206.4587 - mean_absolute_error: 10.7581 - val_loss: 2428.2024 - val_mean_absolute_error: 48.6507
# Epoch 280/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 220.0096 - mean_absolute_error: 10.8622 - val_loss: 2468.3376 - val_mean_absolute_error: 49.0567
# Epoch 281/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 211.7814 - mean_absolute_error: 10.6199 - val_loss: 2273.9268 - val_mean_absolute_error: 47.0438
# Epoch 282/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 200.5525 - mean_absolute_error: 10.4226 - val_loss: 2620.5244 - val_mean_absolute_error: 50.5807
# Epoch 283/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 199.7880 - mean_absolute_error: 10.5698 - val_loss: 2315.6443 - val_mean_absolute_error: 47.4780
# Epoch 284/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 210.9317 - mean_absolute_error: 10.8694 - val_loss: 2714.7666 - val_mean_absolute_error: 51.5004
# Epoch 285/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 200.5117 - mean_absolute_error: 10.4830 - val_loss: 2339.1689 - val_mean_absolute_error: 47.7311
# Epoch 286/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 199.7562 - mean_absolute_error: 10.3210 - val_loss: 2046.4797 - val_mean_absolute_error: 44.5769
# Epoch 287/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 192.1566 - mean_absolute_error: 10.2142 - val_loss: 1806.3560 - val_mean_absolute_error: 41.8086
# Epoch 288/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 217.7351 - mean_absolute_error: 10.9368 - val_loss: 2854.9358 - val_mean_absolute_error: 52.8387
# Epoch 289/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 214.9025 - mean_absolute_error: 10.8095 - val_loss: 1763.4419 - val_mean_absolute_error: 41.2405
# Epoch 290/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 238.9400 - mean_absolute_error: 11.4443 - val_loss: 2522.5686 - val_mean_absolute_error: 49.6006
# Epoch 291/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 219.1094 - mean_absolute_error: 10.9833 - val_loss: 2897.3879 - val_mean_absolute_error: 53.2320
# Epoch 292/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 213.2294 - mean_absolute_error: 10.7249 - val_loss: 2657.8887 - val_mean_absolute_error: 50.9413
# Epoch 293/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 208.9598 - mean_absolute_error: 10.5579 - val_loss: 2439.4749 - val_mean_absolute_error: 48.7662
# Epoch 294/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 227.7965 - mean_absolute_error: 10.9147 - val_loss: 2891.7471 - val_mean_absolute_error: 53.1836
# Epoch 295/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 231.9939 - mean_absolute_error: 11.2103 - val_loss: 3189.5078 - val_mean_absolute_error: 55.9016
# Epoch 296/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 220.0602 - mean_absolute_error: 10.8790 - val_loss: 2247.0383 - val_mean_absolute_error: 46.7576
# Epoch 297/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 218.7467 - mean_absolute_error: 10.9022 - val_loss: 1971.2869 - val_mean_absolute_error: 43.7359
# Epoch 298/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 230.6515 - mean_absolute_error: 11.0670 - val_loss: 2632.1294 - val_mean_absolute_error: 50.6991
# Epoch 299/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 225.1195 - mean_absolute_error: 10.8659 - val_loss: 2292.3315 - val_mean_absolute_error: 47.2483
# Epoch 300/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 197.0497 - mean_absolute_error: 10.2234 - val_loss: 3166.3704 - val_mean_absolute_error: 55.6967
# Epoch 301/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 204.0642 - mean_absolute_error: 10.7703 - val_loss: 1900.4735 - val_mean_absolute_error: 42.9084
# Epoch 302/1000
# ...
# Epoch 901/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 186.4013 - mean_absolute_error: 9.9381 - val_loss: 2310.4749 - val_mean_absolute_error: 47.4357
# Epoch 902/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 211.5418 - mean_absolute_error: 10.5247 - val_loss: 2767.1201 - val_mean_absolute_error: 52.0055
# Epoch 903/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 177.9242 - mean_absolute_error: 9.7464 - val_loss: 3044.0940 - val_mean_absolute_error: 54.5892
# Epoch 904/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 182.8897 - mean_absolute_error: 9.9041 - val_loss: 3224.1624 - val_mean_absolute_error: 56.2031
# Epoch 905/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 193.7926 - mean_absolute_error: 10.2978 - val_loss: 2851.4141 - val_mean_absolute_error: 52.8061
# Epoch 906/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 184.9491 - mean_absolute_error: 10.0833 - val_loss: 2767.9961 - val_mean_absolute_error: 52.0084
# Epoch 907/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 180.8952 - mean_absolute_error: 9.9543 - val_loss: 2888.1907 - val_mean_absolute_error: 53.1445
# Epoch 908/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 180.0331 - mean_absolute_error: 9.7563 - val_loss: 2559.9536 - val_mean_absolute_error: 49.9782
# Epoch 909/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 181.6949 - mean_absolute_error: 9.8689 - val_loss: 2681.5625 - val_mean_absolute_error: 51.1786
# Epoch 910/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 180.4656 - mean_absolute_error: 9.9763 - val_loss: 2985.5969 - val_mean_absolute_error: 54.0604
# Epoch 911/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 170.9146 - mean_absolute_error: 9.5606 - val_loss: 2379.1638 - val_mean_absolute_error: 48.1578
# Epoch 912/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 200.7513 - mean_absolute_error: 10.3022 - val_loss: 3307.1609 - val_mean_absolute_error: 56.9186
# Epoch 913/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 195.2307 - mean_absolute_error: 10.3160 - val_loss: 2070.9861 - val_mean_absolute_error: 44.8221
# Epoch 914/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 189.6969 - mean_absolute_error: 10.2767 - val_loss: 2938.5276 - val_mean_absolute_error: 53.6193
# Epoch 915/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 189.9740 - mean_absolute_error: 9.8781 - val_loss: 2575.3489 - val_mean_absolute_error: 50.1355
# Epoch 916/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 184.3948 - mean_absolute_error: 9.9037 - val_loss: 2521.7737 - val_mean_absolute_error: 49.6116
# Epoch 917/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 192.9332 - mean_absolute_error: 10.2956 - val_loss: 3029.1372 - val_mean_absolute_error: 54.4567
# Epoch 918/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 191.4058 - mean_absolute_error: 10.2134 - val_loss: 2437.1431 - val_mean_absolute_error: 48.7328
# Epoch 919/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 191.3624 - mean_absolute_error: 10.2821 - val_loss: 2683.2664 - val_mean_absolute_error: 51.1961
# Epoch 920/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 178.3687 - mean_absolute_error: 9.9542 - val_loss: 2748.8745 - val_mean_absolute_error: 51.8047
# Epoch 921/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 172.2780 - mean_absolute_error: 9.6726 - val_loss: 2948.8694 - val_mean_absolute_error: 53.7043
# Epoch 922/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 190.1148 - mean_absolute_error: 10.2294 - val_loss: 2699.4944 - val_mean_absolute_error: 51.3526
# Epoch 923/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 193.9825 - mean_absolute_error: 10.1075 - val_loss: 1849.4180 - val_mean_absolute_error: 42.3236
# Epoch 924/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 197.1320 - mean_absolute_error: 10.2606 - val_loss: 2620.3750 - val_mean_absolute_error: 50.5840
# Epoch 925/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 182.0116 - mean_absolute_error: 9.9463 - val_loss: 2892.3223 - val_mean_absolute_error: 53.1824
# Epoch 926/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 184.9727 - mean_absolute_error: 9.9033 - val_loss: 2881.1968 - val_mean_absolute_error: 53.0800
# Epoch 927/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 176.2763 - mean_absolute_error: 9.6695 - val_loss: 2540.1582 - val_mean_absolute_error: 49.7669
# Epoch 928/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 192.3016 - mean_absolute_error: 10.1639 - val_loss: 2752.6958 - val_mean_absolute_error: 51.8486
# Epoch 929/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 176.0307 - mean_absolute_error: 9.8192 - val_loss: 2250.8838 - val_mean_absolute_error: 46.7946
# Epoch 930/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 178.6894 - mean_absolute_error: 9.7704 - val_loss: 2224.2112 - val_mean_absolute_error: 46.5213
# Epoch 931/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 185.4670 - mean_absolute_error: 10.0869 - val_loss: 3206.8525 - val_mean_absolute_error: 56.0468
# Epoch 932/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 168.8204 - mean_absolute_error: 9.6139 - val_loss: 2237.8223 - val_mean_absolute_error: 46.6596
# Epoch 933/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 183.7217 - mean_absolute_error: 10.0120 - val_loss: 3145.4939 - val_mean_absolute_error: 55.5123
# Epoch 934/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 179.2723 - mean_absolute_error: 9.9390 - val_loss: 2593.4731 - val_mean_absolute_error: 50.3014
# Epoch 935/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 204.8244 - mean_absolute_error: 10.5181 - val_loss: 3124.2839 - val_mean_absolute_error: 55.3175
# Epoch 936/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 184.8540 - mean_absolute_error: 9.9979 - val_loss: 2995.1614 - val_mean_absolute_error: 54.1507
# Epoch 937/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 189.9706 - mean_absolute_error: 9.9276 - val_loss: 2652.8728 - val_mean_absolute_error: 50.8927
# Epoch 938/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 178.7474 - mean_absolute_error: 9.7968 - val_loss: 3079.4521 - val_mean_absolute_error: 54.9005
# Epoch 939/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 195.3749 - mean_absolute_error: 10.2670 - val_loss: 2860.5195 - val_mean_absolute_error: 52.8910
# Epoch 940/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 176.4561 - mean_absolute_error: 9.7311 - val_loss: 2042.5339 - val_mean_absolute_error: 44.5457
# Epoch 941/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 166.8223 - mean_absolute_error: 9.5228 - val_loss: 2825.2915 - val_mean_absolute_error: 52.5525
# Epoch 942/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 187.6264 - mean_absolute_error: 9.9785 - val_loss: 2908.5986 - val_mean_absolute_error: 53.3495
# Epoch 943/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 177.6139 - mean_absolute_error: 9.8310 - val_loss: 2760.0332 - val_mean_absolute_error: 51.9470
# Epoch 944/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 199.6727 - mean_absolute_error: 9.9983 - val_loss: 3096.7190 - val_mean_absolute_error: 55.0752
# Epoch 945/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 185.9547 - mean_absolute_error: 10.0685 - val_loss: 2826.2317 - val_mean_absolute_error: 52.5724
# Epoch 946/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 185.5871 - mean_absolute_error: 9.9038 - val_loss: 3187.8835 - val_mean_absolute_error: 55.8903
# Epoch 947/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 172.1621 - mean_absolute_error: 9.5320 - val_loss: 3082.3604 - val_mean_absolute_error: 54.9338
# Epoch 948/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 192.5251 - mean_absolute_error: 10.1831 - val_loss: 3072.6782 - val_mean_absolute_error: 54.8503
# Epoch 949/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 202.0241 - mean_absolute_error: 10.3473 - val_loss: 2988.5295 - val_mean_absolute_error: 54.0779
# Epoch 950/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 180.8858 - mean_absolute_error: 9.8952 - val_loss: 2758.1355 - val_mean_absolute_error: 51.9134
# Epoch 951/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 181.2666 - mean_absolute_error: 9.6871 - val_loss: 2395.9675 - val_mean_absolute_error: 48.2948
# Epoch 952/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 181.4017 - mean_absolute_error: 9.7453 - val_loss: 2658.0186 - val_mean_absolute_error: 50.9356
# Epoch 953/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 184.4438 - mean_absolute_error: 9.9689 - val_loss: 2432.7156 - val_mean_absolute_error: 48.6976
# Epoch 954/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 199.6013 - mean_absolute_error: 10.2053 - val_loss: 2747.4402 - val_mean_absolute_error: 51.8092
# Epoch 955/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 181.2706 - mean_absolute_error: 9.8658 - val_loss: 3009.5608 - val_mean_absolute_error: 54.2757
# Epoch 956/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 190.0890 - mean_absolute_error: 9.8159 - val_loss: 2873.2617 - val_mean_absolute_error: 53.0112
# Epoch 957/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 177.8125 - mean_absolute_error: 9.8869 - val_loss: 2582.7271 - val_mean_absolute_error: 50.2170
# Epoch 958/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 191.1636 - mean_absolute_error: 10.0571 - val_loss: 2886.5076 - val_mean_absolute_error: 53.1401
# Epoch 959/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 187.1675 - mean_absolute_error: 10.0616 - val_loss: 3218.1560 - val_mean_absolute_error: 56.1577
# Epoch 960/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 199.8561 - mean_absolute_error: 10.4879 - val_loss: 2717.1929 - val_mean_absolute_error: 51.5112
# Epoch 961/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 179.9915 - mean_absolute_error: 9.8718 - val_loss: 2647.3157 - val_mean_absolute_error: 50.8547
# Epoch 962/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 189.3835 - mean_absolute_error: 9.9944 - val_loss: 2391.3137 - val_mean_absolute_error: 48.2835
# Epoch 963/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 176.8431 - mean_absolute_error: 9.5493 - val_loss: 3581.4731 - val_mean_absolute_error: 59.2883
# Epoch 964/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 204.1625 - mean_absolute_error: 10.2268 - val_loss: 2997.2449 - val_mean_absolute_error: 54.1631
# Epoch 965/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 184.5286 - mean_absolute_error: 10.0188 - val_loss: 2556.1814 - val_mean_absolute_error: 49.9390
# Epoch 966/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 174.8927 - mean_absolute_error: 9.5132 - val_loss: 2804.5935 - val_mean_absolute_error: 52.3632
# Epoch 967/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 177.2538 - mean_absolute_error: 9.7775 - val_loss: 2972.7690 - val_mean_absolute_error: 53.9334
# Epoch 968/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 169.6412 - mean_absolute_error: 9.4340 - val_loss: 3242.4348 - val_mean_absolute_error: 56.3644
# Epoch 969/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 186.8983 - mean_absolute_error: 9.9527 - val_loss: 1907.0482 - val_mean_absolute_error: 42.9579
# Epoch 970/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 203.3614 - mean_absolute_error: 10.3164 - val_loss: 3063.1509 - val_mean_absolute_error: 54.7564
# Epoch 971/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 188.4119 - mean_absolute_error: 10.0719 - val_loss: 3185.2598 - val_mean_absolute_error: 55.8402
# Epoch 972/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 189.4476 - mean_absolute_error: 9.9752 - val_loss: 2603.6558 - val_mean_absolute_error: 50.3873
# Epoch 973/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 191.2279 - mean_absolute_error: 10.2836 - val_loss: 2518.5168 - val_mean_absolute_error: 49.5730
# Epoch 974/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 175.2707 - mean_absolute_error: 9.8135 - val_loss: 2987.4719 - val_mean_absolute_error: 54.0795
# Epoch 975/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 172.2108 - mean_absolute_error: 9.6822 - val_loss: 2878.1572 - val_mean_absolute_error: 53.0551
# Epoch 976/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 188.4843 - mean_absolute_error: 9.9420 - val_loss: 2836.5457 - val_mean_absolute_error: 52.6663
# Epoch 977/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 200.7483 - mean_absolute_error: 10.4635 - val_loss: 3588.5327 - val_mean_absolute_error: 59.3339
# Epoch 978/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 214.1688 - mean_absolute_error: 10.8715 - val_loss: 2749.0576 - val_mean_absolute_error: 51.8298
# Epoch 979/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 191.6651 - mean_absolute_error: 9.9060 - val_loss: 2834.6196 - val_mean_absolute_error: 52.6055
# Epoch 980/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 199.9600 - mean_absolute_error: 10.4929 - val_loss: 2925.0642 - val_mean_absolute_error: 53.4843
# Epoch 981/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 177.3158 - mean_absolute_error: 9.8175 - val_loss: 3469.7959 - val_mean_absolute_error: 58.3397
# Epoch 982/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 199.0065 - mean_absolute_error: 10.3441 - val_loss: 2921.4905 - val_mean_absolute_error: 53.4548
# Epoch 983/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 190.7410 - mean_absolute_error: 9.9009 - val_loss: 2745.9365 - val_mean_absolute_error: 51.7999
# Epoch 984/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 179.2424 - mean_absolute_error: 9.9979 - val_loss: 3134.1008 - val_mean_absolute_error: 55.4031
# Epoch 985/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 198.0390 - mean_absolute_error: 10.3365 - val_loss: 3007.0256 - val_mean_absolute_error: 54.2448
# Epoch 986/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 199.5796 - mean_absolute_error: 10.3817 - val_loss: 2439.4246 - val_mean_absolute_error: 48.7721
# Epoch 987/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 188.6521 - mean_absolute_error: 10.0620 - val_loss: 2950.7700 - val_mean_absolute_error: 53.7320
# Epoch 988/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 188.8618 - mean_absolute_error: 10.2800 - val_loss: 2729.0908 - val_mean_absolute_error: 51.6511
# Epoch 989/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 195.4824 - mean_absolute_error: 10.0780 - val_loss: 2786.2949 - val_mean_absolute_error: 52.1699
# Epoch 990/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 185.8645 - mean_absolute_error: 9.9521 - val_loss: 2702.3992 - val_mean_absolute_error: 51.3771
# Epoch 991/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 184.4653 - mean_absolute_error: 10.0629 - val_loss: 3272.6646 - val_mean_absolute_error: 56.6334
# Epoch 992/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 186.0587 - mean_absolute_error: 9.8333 - val_loss: 2533.1545 - val_mean_absolute_error: 49.7109
# Epoch 993/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 175.8504 - mean_absolute_error: 9.6847 - val_loss: 2482.3286 - val_mean_absolute_error: 49.1915
# Epoch 994/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 181.8410 - mean_absolute_error: 9.8768 - val_loss: 2592.5212 - val_mean_absolute_error: 50.3017
# Epoch 995/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 201.5725 - mean_absolute_error: 10.5836 - val_loss: 2064.6697 - val_mean_absolute_error: 44.7822
# Epoch 996/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 193.6502 - mean_absolute_error: 10.1933 - val_loss: 3470.4067 - val_mean_absolute_error: 58.3420
# Epoch 997/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 187.8317 - mean_absolute_error: 10.1940 - val_loss: 2183.3345 - val_mean_absolute_error: 46.0667
# Epoch 998/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 180.5594 - mean_absolute_error: 9.9279 - val_loss: 2247.9504 - val_mean_absolute_error: 46.7722
# Epoch 999/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 209.5096 - mean_absolute_error: 10.5025 - val_loss: 2387.7993 - val_mean_absolute_error: 48.2370
# Epoch 1000/1000
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 182.0518 - mean_absolute_error: 9.8782 - val_loss: 2618.5479 - val_mean_absolute_error: 50.5664

# %%
# Find the epoch for the lowest MAE for training and validation
min_train_mae = min(history.history['mean_absolute_error'])
min_val_mae = min(history.history['val_mean_absolute_error'])

min_train_loss = min(history.history['loss'])
min_val_loss = min(history.history['val_loss'])

min_train_mae_epoch = history.history['mean_absolute_error'].index(min_train_mae) + 1
min_val_mae_epoch = history.history['val_mean_absolute_error'].index(min_val_mae) + 1

# Find the epoch for the lowest loss for training and validation
min_train_loss_epoch = history.history['loss'].index(min_train_loss) + 1
min_val_loss_epoch = history.history['val_loss'].index(min_val_loss) + 1

print("Lowest MAE for training: {:.4f} at epoch {}".format(min_train_mae, min_train_mae_epoch))
print("Lowest MAE for validation: {:.4f} at epoch {}".format(min_val_mae, min_val_mae_epoch))

print("Lowest loss for training: {:.4f} at epoch {}".format(min_train_loss, min_train_loss_epoch))
print("Lowest loss for validation: {:.4f} at epoch {}".format(min_val_loss, min_val_loss_epoch))

# %%
from keras.models import load_model
loaded_model = load_model ('best_model_SimpleRNN_3_tanh.keras')

loss, mae = loaded_model.evaluate(X_valid, y_valid)

print("Validation Loss:", loss)
print("Validation Mean Absolute Error:", mae)

# %%
y_pred = loaded_model.predict(X_valid)

# %%
import matplotlib.pyplot as plt

# Assuming timestamps are available for both y_pred and y_valid
timestamps = range(len(y_valid))

# Plot y_pred vs y_valid
plt.figure(figsize=(10, 6))
plt.plot(timestamps, y_valid, label='Actual', color='blue')
plt.plot(timestamps, y_pred, label='Predicted', color='red')
plt.title('Actual vs Predicted Time Series')
plt.xlabel('Time')
plt.ylabel('Value')
plt.legend()
plt.show()
